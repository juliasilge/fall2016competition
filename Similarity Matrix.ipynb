# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import hdbscan
import seaborn as sns
sns.set_style("dark")

# %%
pd.set_option('max_colwidth', 1000)

# %% [markdown]
# # Load Data
#
# Here, I'm reading in the imputed data set Julia put together, and pulling in some metadata from the non-imputed data.

# %%
data = pd.read_csv('data/scorecard_reduced_features.csv')
imputed = pd.read_csv('data/scorecard_imputed.csv')
imputed['UNITID'] = data.UNITID

# %% [markdown]
# Set the index to the UNITID, and inspect the dataframes:

# %%
data.set_index('UNITID', inplace=True)
data.head()
# Out:
#                                      INSTNM         ZIP  HCM2  CONTROL  \
# UNITID
# 100654             Alabama A & M University       35762   0.0      1.0
# 100663  University of Alabama at Birmingham  35294-0110   0.0      1.0
# 100690                   Amridge University  36117-3553   0.0      2.0
# 100706  University of Alabama in Huntsville       35899   0.0      1.0
# 100724             Alabama State University  36104-0271   0.0      1.0
#
#         LOCALE  CCBASIC  CCUGPROF  CCSIZSET  HBCU  PBI       ...        \
# UNITID                                                       ...
# 100654    12.0     18.0       9.0      14.0   1.0  0.0       ...
# 100663    12.0     15.0       8.0      15.0   0.0  0.0       ...
# 100690    12.0     21.0       6.0       6.0   0.0  0.0       ...
# 100706    12.0     15.0       8.0      12.0   0.0  0.0       ...
# 100724    12.0     18.0       9.0      13.0   1.0  0.0       ...
#
#         LO_INC_RPY_3YR_RT_SUPP  MD_INC_RPY_3YR_RT_SUPP  \
# UNITID
# 100654                0.448163                0.446488
# 100663                0.724256                0.770134
# 100690                0.597701                0.709091
# 100706                0.721404                0.824742
# 100724                0.310875                0.376106
#
#         HI_INC_RPY_3YR_RT_SUPP  NONCOM_RPY_3YR_RT_SUPP  \
# UNITID
# 100654                0.422018                0.373790
# 100663                0.818059                0.678749
# 100690                     NaN                0.613281
# 100706                0.851936                0.689788
# 100724                0.333333                0.315997
#
#         FIRSTGEN_RPY_3YR_RT_SUPP  PCT_LIBERAL_ARTS  PCT_PROFESSIONAL  \
# UNITID
# 100654                  0.423581            0.5346            0.4074
# 100663                  0.751553            0.4379            0.5805
# 100690                  0.632653            0.6301            0.1096
# 100706                  0.778157            0.2764            0.7152
# 100724                  0.315737            0.5449            0.5733
#
#         PCT_RELIGIOUS     COST  PCT_VOCATIONAL
# UNITID
# 100654         0.0000  18888.0          0.0629
# 100663         0.0095  19990.0          0.0000
# 100690         0.2603  12300.0          0.0000
# 100706         0.0082  20306.0          0.0000
# 100724         0.0000  17400.0          0.0000
#
# [5 rows x 58 columns]

# %%
imputed.set_index('UNITID', inplace=True)
imputed.head()
# Out:
#         HCM2  CONTROL  LOCALE  CCBASIC  HBCU  PBI  ANNHI  TRIBAL  AANAPII  \
# UNITID
# 100654     0        1      12       18     1    0      0       0        0
# 100663     0        1      12       15     0    0      0       0        0
# 100690     0        2      12       21     0    0      0       0        0
# 100706     0        1      12       15     0    0      0       0        0
# 100724     0        1      12       18     1    0      0       0        0
#
#         HSI        ...         LO_INC_RPY_3YR_RT_SUPP  MD_INC_RPY_3YR_RT_SUPP  \
# UNITID             ...
# 100654    0        ...                       0.448163                0.446488
# 100663    0        ...                       0.724256                0.770134
# 100690    0        ...                       0.597701                0.709091
# 100706    0        ...                       0.721404                0.824742
# 100724    0        ...                       0.310875                0.376106
#
#         HI_INC_RPY_3YR_RT_SUPP  NONCOM_RPY_3YR_RT_SUPP  \
# UNITID
# 100654                0.422018                0.373790
# 100663                0.818059                0.678749
# 100690                0.788065                0.613281
# 100706                0.851936                0.689788
# 100724                0.333333                0.315997
#
#         FIRSTGEN_RPY_3YR_RT_SUPP  PCT_LIBERAL_ARTS  PCT_VOCATIONAL  \
# UNITID
# 100654                  0.423581            0.5346          0.0629
# 100663                  0.751553            0.4379          0.0000
# 100690                  0.632653            0.6301          0.0000
# 100706                  0.778157            0.2764          0.0000
# 100724                  0.315737            0.5449          0.0000
#
#         PCT_RELIGIOUS     COST  PCT_PROFESSIONAL
# UNITID
# 100654         0.0000  18888.0            0.4074
# 100663         0.0095  19990.0            0.5805
# 100690         0.2603  12300.0            0.1096
# 100706         0.0082  20306.0            0.7152
# 100724         0.0000  17400.0            0.5733
#
# [5 rows x 54 columns]

# %% [markdown]
# Everything matches up. Good!
#
#
# We can use `pandas.get_dummies()` to break out the categorical columns and improve the performace of our cosine similarity metric.

# %%
imputed = pd.get_dummies(imputed, columns=['CONTROL', 'LOCALE', 'CCBASIC'])#, 'CCUGPROF', 'CCSIZSET'])

# %% [markdown]
# Then, to make sure all features are treated equally, normalize them to the range 0-1.

# %%
rescaled = MinMaxScaler().fit_transform(imputed)
imputed[imputed.columns] = rescaled

# %%
rescaled.shape
# Out:
# (2473, 93)

# %% [markdown]
# # Compute the cosine similarity:
#
# Import from scikit-learn and let it do all the work :-)

# %%
from sklearn.metrics.pairwise import cosine_similarity

c = cosine_similarity(rescaled, rescaled)

# %% [markdown]
# That returns a square numpy array with the similarity of each school to every other.  Now we need to pipe it back into a dataframe so we can keep everything indexed:

# %%
cosim = pd.DataFrame(c, index=data.index, columns=data.index)
cosim['INSTNM'] = data.INSTNM
cosim['ZIP'] = data.ZIP

# %% [markdown]
# Rearrange the columns so INSTNM and ZIP are at the front:

# %%
cols = cosim.columns.tolist()
cosim = cosim[cols[-2:]+cols[:-2]]

cosim.head()
# Out:
# UNITID                               INSTNM         ZIP    100654    100663  \
# UNITID
# 100654             Alabama A & M University       35762  1.000000  0.751817
# 100663  University of Alabama at Birmingham  35294-0110  0.751817  1.000000
# 100690                   Amridge University  36117-3553  0.649907  0.790216
# 100706  University of Alabama in Huntsville       35899  0.721509  0.991159
# 100724             Alabama State University  36104-0271  0.928033  0.663715
#
# UNITID    100690    100706    100724    100751    100812    100830    ...     \
# UNITID                                                                ...
# 100654  0.649907  0.721509  0.928033  0.622077  0.618940  0.849199    ...
# 100663  0.790216  0.991159  0.663715  0.842650  0.811736  0.878556    ...
# 100690  1.000000  0.764079  0.589172  0.693059  0.706366  0.769680    ...
# 100706  0.764079  1.000000  0.629289  0.837913  0.815738  0.866514    ...
# 100724  0.589172  0.629289  1.000000  0.522988  0.539998  0.785523    ...
#
# UNITID  45891904  45891905  45891906  45891907  45896401  45896402  45897301  \
# UNITID
# 100654  0.481003  0.481003  0.481003  0.481003  0.481003  0.481003  0.481003
# 100663  0.586366  0.586366  0.586366  0.586366  0.586366  0.586366  0.586366
# 100690  0.605232  0.605232  0.605232  0.605232  0.605232  0.605232  0.605232
# 100706  0.588891  0.588891  0.588891  0.588891  0.588891  0.588891  0.588891
# 100724  0.449587  0.449587  0.449587  0.449587  0.449587  0.449587  0.449587
#
# UNITID  45897302  45897303  45897304
# UNITID
# 100654  0.481003  0.481003  0.481003
# 100663  0.586366  0.586366  0.586366
# 100690  0.605232  0.605232  0.605232
# 100706  0.588891  0.588891  0.588891
# 100724  0.449587  0.449587  0.449587
#
# [5 rows x 2475 columns]

# %% [markdown]
# # Look at a few examples:

# %%
cosim[cosim.INSTNM.str.contains('Harvard')]['INSTNM']
# Out:
# UNITID
# 166027    Harvard University
# Name: INSTNM, dtype: object

# %%
cosim[['INSTNM', 166027]].sort_values(166027, ascending=False).head(15)
# Out:
# UNITID                                       INSTNM    166027
# UNITID
# 166027                           Harvard University  1.000000
# 130794                              Yale University  0.991084
# 198419                              Duke University  0.983294
# 217156                             Brown University  0.980329
# 166683        Massachusetts Institute of Technology  0.979921
# 195030                      University of Rochester  0.955522
# 110404           California Institute of Technology  0.949982
# 243744                          Stanford University  0.947793
# 182670                            Dartmouth College  0.944073
# 190150  Columbia University in the City of New York  0.942211
# 215062                   University of Pennsylvania  0.942077
# 131496                        Georgetown University  0.938292
# 144050                        University of Chicago  0.938230
# 186131                         Princeton University  0.937236
# 147767                      Northwestern University  0.937154

# %%
cosim[cosim.INSTNM.str.contains('Truman')]['INSTNM']
# Out:
# UNITID
# 178615    Truman State University
# Name: INSTNM, dtype: object

# %%
cosim[['INSTNM', 178615]].sort_values(178615, ascending=False).head(15)
# Out:
# UNITID                                    INSTNM    178615
# UNITID
# 178615                   Truman State University  1.000000
# 232566                       Longwood University  0.986828
# 171456              Northern Michigan University  0.971974
# 221768        The University of Tennessee-Martin  0.964441
# 175078      Southwest Minnesota State University  0.959259
# 115755                 Humboldt State University  0.954898
# 200253                    Minot State University  0.936694
# 107983  Southern Arkansas University Main Campus  0.935894
# 207865    Southwestern Oklahoma State University  0.927232
# 217819                     College of Charleston  0.924331
# 176017                 University of Mississippi  0.923244
# 176080              Mississippi State University  0.923026
# 174251            University of Minnesota-Morris  0.922963
# 240480     University of Wisconsin-Stevens Point  0.922555
# 196185                              SUNY Oneonta  0.922254

# %%
cosim[cosim.INSTNM.str.contains('University of Utah')]['INSTNM']
# Out:
# UNITID
# 230764    University of Utah
# Name: INSTNM, dtype: object

# %%
cosim[['INSTNM', 230764]].sort_values(230764, ascending=False).head(15)
# Out:
# UNITID                                     INSTNM    230764
# UNITID
# 230764                         University of Utah  1.000000
# 126818     Colorado State University-Fort Collins  0.991681
# 221759      The University of Tennessee-Knoxville  0.990772
# 104151             Arizona State University-Tempe  0.990071
# 209551                       University of Oregon  0.986680
# 178396            University of Missouri-Columbia  0.985976
# 200332  North Dakota State University-Main Campus  0.985357
# 234030           Virginia Commonwealth University  0.984573
# 218663      University of South Carolina-Columbia  0.983945
# 100663        University of Alabama at Birmingham  0.983192
# 240444            University of Wisconsin-Madison  0.982074
# 100706        University of Alabama in Huntsville  0.981265
# 139959                      University of Georgia  0.980353
# 134097                   Florida State University  0.973631
# 134130                      University of Florida  0.963629

# %%
cosim[cosim.INSTNM.str.contains('University of Texas at Austin')]['INSTNM']
# Out:
# UNITID
# 228778    The University of Texas at Austin
# Name: INSTNM, dtype: object

# %%
cosim[['INSTNM', 228778]].sort_values(228778, ascending=False).head(15)
# Out:
# UNITID                                       INSTNM    228778
# UNITID
# 228778            The University of Texas at Austin  1.000000
# 236948      University of Washington-Seattle Campus  0.993856
# 110680           University of California-San Diego  0.992566
# 174066          University of Minnesota-Twin Cities  0.991074
# 139755  Georgia Institute of Technology-Main Campus  0.990308
# 110662         University of California-Los Angeles  0.990089
# 204796            Ohio State University-Main Campus  0.989203
# 199193   North Carolina State University at Raleigh  0.986759
# 137351      University of South Florida-Main Campus  0.986201
# 145600            University of Illinois at Chicago  0.983303
# 215293   University of Pittsburgh-Pittsburgh Campus  0.983000
# 181464               University of Nebraska-Lincoln  0.982441
# 104179                        University of Arizona  0.980780
# 139940                     Georgia State University  0.978098
# 157085                       University of Kentucky  0.977878

# %%
cosim[cosim.INSTNM.str.contains('Missouri University of Science and Technology')]['INSTNM']
# Out:
# UNITID
# 178411    Missouri University of Science and Technology
# Name: INSTNM, dtype: object

# %%
cosim[['INSTNM', 178411]].sort_values(178411, ascending=False).head(15)
# Out:
# UNITID                                             INSTNM    178411
# UNITID
# 178411      Missouri University of Science and Technology  1.000000
# 171128                  Michigan Technological University  0.976027
# 219356                      South Dakota State University  0.958949
# 176017                          University of Mississippi  0.958815
# 240727                              University of Wyoming  0.957252
# 100858                                  Auburn University  0.918862
# 151111  Indiana University-Purdue University-Indianapolis  0.898489
# 180461                           Montana State University  0.897983
# 155399                            Kansas State University  0.895094
# 190044                                Clarkson University  0.894822
# 200280                         University of North Dakota  0.894614
# 166513                 University of Massachusetts-Lowell  0.894316
# 178615                            Truman State University  0.893722
# 229115                              Texas Tech University  0.893103
# 207388              Oklahoma State University-Main Campus  0.892309

# %%
cosim[cosim.INSTNM.str.contains('California Institute of Technology')]['INSTNM']
# Out:
# UNITID
# 110404    California Institute of Technology
# Name: INSTNM, dtype: object

# %%
cosim[['INSTNM', 110404]].sort_values(110404, ascending=False).head(15)
# Out:
# UNITID                                 INSTNM    110404
# UNITID
# 110404     California Institute of Technology  1.000000
# 166683  Massachusetts Institute of Technology  0.975299
# 195030                University of Rochester  0.963670
# 217156                       Brown University  0.962175
# 198419                        Duke University  0.961115
# 130794                        Yale University  0.959402
# 166027                     Harvard University  0.949982
# 211440             Carnegie Mellon University  0.925095
# 227757                        Rice University  0.924326
# 186131                   Princeton University  0.922532
# 110635      University of California-Berkeley  0.922375
# 243744                    Stanford University  0.922032
# 147767                Northwestern University  0.919396
# 190415                     Cornell University  0.918733
# 182670                      Dartmouth College  0.917692

# %%
cosim[cosim.INSTNM.str.contains('Stanford')]['INSTNM']
# Out:
# UNITID
# 243744    Stanford University
# Name: INSTNM, dtype: object

# %%
cosim[['INSTNM', 243744]].sort_values(243744, ascending=False).head(15)
# Out:
# UNITID                             INSTNM    243744
# UNITID
# 243744                Stanford University  1.000000
# 186131               Princeton University  0.985658
# 179867  Washington University in St Louis  0.984672
# 139658                   Emory University  0.983616
# 168148                   Tufts University  0.982359
# 152080           University of Notre Dame  0.981309
# 135726                University of Miami  0.978513
# 130794                    Yale University  0.952529
# 215062         University of Pennsylvania  0.950277
# 198419                    Duke University  0.949768
# 182670                  Dartmouth College  0.949758
# 190415                 Cornell University  0.948864
# 166027                 Harvard University  0.947793
# 144050              University of Chicago  0.947224
# 147767            Northwestern University  0.946177

# %%
cosim[cosim.INSTNM.str.contains('Brigham Young')]['INSTNM']
# Out:
# UNITID
# 142522     Brigham Young University-Idaho
# 230038     Brigham Young University-Provo
# 230047    Brigham Young University-Hawaii
# Name: INSTNM, dtype: object

# %%
cosim[['INSTNM', 230038]].sort_values(230038, ascending=False).head(15)
# Out:
# UNITID                            INSTNM    230038
# UNITID
# 230038    Brigham Young University-Provo  1.000000
# 223232                 Baylor University  0.971371
# 199847            Wake Forest University  0.970221
# 165334                  Clark University  0.970007
# 202480              University of Dayton  0.963099
# 196413               Syracuse University  0.960718
# 21997601                           Spark  0.913005
# 229115             Texas Tech University  0.911639
# 143358                Bradley University  0.910920
# 130590                   Trinity College  0.910704
# 459736       Touro University California  0.910164
# 236328         University of Puget Sound  0.909869
# 213543                 Lehigh University  0.908818
# 175980                  Millsaps College  0.908448
# 235316                Gonzaga University  0.908320

# %%
cosim[cosim.INSTNM.str.contains('Calvin College')]
# Out:
# UNITID          INSTNM    ZIP    100654    100663    100690    100706  \
# UNITID
# 169080  Calvin College  49546  0.635261  0.827865  0.893868  0.821693
#
# UNITID    100724    100751    100812    100830    ...     45891904  45891905  \
# UNITID                                            ...
# 169080  0.535021  0.773005  0.736335  0.793831    ...     0.544573  0.544573
#
# UNITID  45891906  45891907  45896401  45896402  45897301  45897302  45897303  \
# UNITID
# 169080  0.544573  0.544573  0.544573  0.544573  0.544573  0.544573  0.544573
#
# UNITID  45897304
# UNITID
# 169080  0.544573
#
# [1 rows x 2475 columns]

# %%
cosim[['INSTNM', 169080]].sort_values(169080, ascending=False).head(15)
# Out:
# UNITID                          INSTNM    169080
# UNITID
# 169080                  Calvin College  1.000000
# 175980                Millsaps College  0.984742
# 153144                     Coe College  0.980639
# 236328       University of Puget Sound  0.978813
# 210401           Willamette University  0.976808
# 158477  Centenary College of Louisiana  0.975647
# 130590                 Trinity College  0.965384
# 233374          University of Richmond  0.963268
# 100937     Birmingham Southern College  0.960006
# 133492                  Eckerd College  0.957875
# 214175              Muhlenberg College  0.952595
# 166124       College of the Holy Cross  0.952287
# 455770    Providence Christian College  0.952201
# 165936                  Gordon College  0.932976
# 153834                  Luther College  0.931749

# %%
cosim[cosim.INSTNM.str.contains('Spark')]
# Out:
# UNITID   INSTNM        ZIP    100654    100663    100690    100706    100724  \
# UNITID
# 21997601  Spark  370674896  0.617134  0.830971  0.843138  0.830644  0.520759
#
# UNITID      100751    100812    100830    ...     45891904  45891905  \
# UNITID                                    ...
# 21997601  0.769498  0.731664  0.775266    ...     0.555322  0.555322
#
# UNITID    45891906  45891907  45896401  45896402  45897301  45897302  \
# UNITID
# 21997601  0.555322  0.555322  0.555322  0.555322  0.555322  0.555322
#
# UNITID    45897303  45897304
# UNITID
# 21997601  0.555322  0.555322
#
# [1 rows x 2475 columns]

# %%
cosim[['INSTNM', 21997601]].sort_values(21997601, ascending=False).head(15)
# Out:
# UNITID                                                      INSTNM  21997601
# UNITID
# 21997601                                                     Spark  1.000000
# 16822703                         Wentworth Institute of Technology  0.996240
# 16822702                         Wentworth Institute of Technology  0.996240
# 16822701                         Wentworth Institute of Technology  0.996240
# 233842                                 Union Presbyterian Seminary  0.995181
# 459736                                 Touro University California  0.994521
# 120795                                  Pacific School of Religion  0.994360
# 165705                                   Episcopal Divinity School  0.994082
# 169099                                 Calvin Theological Seminary  0.994061
# 14736901  Moody Theological Seminary and Graduate School--Michigan  0.993330
# 14736902                             Moody Bible Institute-Spokane  0.993330
# 108861                       American Baptist Seminary of the West  0.992627
# 176619                      Assemblies of God Theological Seminary  0.992557
# 112127                       Church Divinity School of the Pacific  0.990134
# 219240                                        Sioux Falls Seminary  0.989222

# %%
cosim[cosim.INSTNM.str.contains('Lipscomb')]
# Out:
# UNITID               INSTNM         ZIP    100654    100663    100690  100706  \
# UNITID
# 219976  Lipscomb University  37204-3951  0.634802  0.755495  0.756662  0.7517
#
# UNITID    100724   100751    100812    100830    ...     45891904  45891905  \
# UNITID                                           ...
# 219976  0.541427  0.76086  0.730206  0.790897    ...      0.55573   0.55573
#
# UNITID  45891906  45891907  45896401  45896402  45897301  45897302  45897303  \
# UNITID
# 219976   0.55573   0.55573   0.55573   0.55573   0.55573   0.55573   0.55573
#
# UNITID  45897304
# UNITID
# 219976   0.55573
#
# [1 rows x 2475 columns]

# %%
cosim[['INSTNM', 219976]].sort_values(219976, ascending=False).head(15)
# Out:
# UNITID                          INSTNM    219976
# UNITID
# 219976             Lipscomb University  1.000000
# 137847         The University of Tampa  0.989842
# 173045                Augsburg College  0.984756
# 121309  Point Loma Nazarene University  0.984000
# 151263      University of Indianapolis  0.983916
# 147679           North Park University  0.982748
# 159656   Loyola University New Orleans  0.982465
# 207458        Oklahoma City University  0.979085
# 181002            Creighton University  0.978569
# 173665              Hamline University  0.978411
# 209825          University of Portland  0.976981
# 189705                Canisius College  0.976682
# 169716     University of Detroit Mercy  0.974092
# 236577      Seattle Pacific University  0.973068
# 156286           Bellarmine University  0.972850

# %% [markdown]
# ### LEAST similar schools to Harvard:

# %%
cosim[['INSTNM', 439279]].sort_values(439279, ascending=False).head(30)
# Out:
# UNITID                                             INSTNM    439279
# UNITID
# 439279              University of Phoenix-St Louis Campus  1.000000
# 450456            University of Phoenix-Birmingham Campus  0.869044
# 450474               University of Phoenix-Augusta Campus  0.867255
# 474960             University of Phoenix-Lafayette Campus  0.866714
# 450483         University of Phoenix-Washington DC Campus  0.866571
# 448567              University of Phoenix-Columbia Campus  0.866332
# 442161               University of Phoenix-Chicago Campus  0.865762
# 474951           University of Phoenix-Baton Rouge Campus  0.865282
# 440448               University of Phoenix-Houston Campus  0.864291
# 448822      University of Phoenix-Fairfield County Campus  0.863010
# 474979    University of Phoenix-Shreveport-Bossier Campus  0.862969
# 443924           University of Phoenix-Little Rock Campus  0.861968
# 446747                University of Phoenix-Austin Campus  0.859771
# 443474             University of Phoenix-Charlotte Campus  0.858010
# 421009             University of Phoenix-Louisiana Campus  0.857739
# 440457             University of Phoenix-Milwaukee Campus  0.856873
# 443766                       Strayer University-Tennessee  0.856101
# 450377                         Strayer University-Alabama  0.851748
# 442170             University of Phoenix-Nashville Campus  0.851702
# 450298                        Strayer University-Delaware  0.851597
# 44903803           Strayer University-Orlando East Campus  0.851580
# 44903802               Strayer University-Maitland Campus  0.851580
# 44903801             Strayer University-Tampa East Campus  0.851580
# 44378401        Strayer University-Delaware County Campus  0.851580
# 44378406              Strayer University-Allentown Campus  0.851580
# 44378405             Strayer University-Warrendale Campus  0.851580
# 44378403            Strayer University-Center City Campus  0.851580
# 45891902                 Strayer University-Morrow Campus  0.851580
# 44376603              Strayer University-Knoxville Campus  0.851580
# 44376602            Strayer University-Shelby Oaks Campus  0.851580

# %% [markdown]
# ## I'm amazed how much better a job this is doing just splitting out the categorical variables!!!

# %% [markdown]
# # Finally, save to csv.

# %%
cosim.to_csv('data/similarity_index.csv')

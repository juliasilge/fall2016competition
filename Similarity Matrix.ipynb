# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
import hdbscan
import seaborn as sns
sns.set_style("dark")
# Out:
# /home/jhummel/anaconda/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
pd.set_option('max_colwidth', 1000)

# %% [markdown]
# # Load Data
#
# Here, I'm reading in the imputed data set Julia put together, and pulling in some metadata from the non-imputed data.

# %%
data = pd.read_csv('data/scorecard_reduced_features.csv')
imputed = pd.read_csv('data/scorecard_imputed.csv')

# %% [markdown]
# Then, to make sure all features are treated equally, normalize them to the range 0-1.

# %%
rescaled = MinMaxScaler().fit_transform(imputed)
data[imputed.columns] = rescaled

# %% [markdown]
# Set the index of the resulting dataset to the UNITID, and inspect the dataframe:

# %%
data.set_index('UNITID', inplace=True)
data.head()
# Out:
#                                      INSTNM         ZIP  HCM2  CONTROL  \
# UNITID
# 100654             Alabama A & M University       35762   0.0      0.0
# 100663  University of Alabama at Birmingham  35294-0110   0.0      0.0
# 100690                   Amridge University  36117-3553   0.0      0.5
# 100706  University of Alabama in Huntsville       35899   0.0      0.0
# 100724             Alabama State University  36104-0271   0.0      0.0
#
#          LOCALE  CCBASIC  HBCU  PBI  ANNHI  TRIBAL        ...         \
# UNITID                                                    ...
# 100654  0.03125  0.53125   1.0  0.0    0.0     0.0        ...
# 100663  0.03125  0.43750   0.0  0.0    0.0     0.0        ...
# 100690  0.03125  0.62500   0.0  0.0    0.0     0.0        ...
# 100706  0.03125  0.43750   0.0  0.0    0.0     0.0        ...
# 100724  0.03125  0.53125   1.0  0.0    0.0     0.0        ...
#
#         LO_INC_RPY_3YR_RT_SUPP  MD_INC_RPY_3YR_RT_SUPP  \
# UNITID
# 100654                0.388809                0.334182
# 100663                0.694598                0.723495
# 100690                0.554431                0.650066
# 100706                0.691439                0.789183
# 100724                0.236754                0.249519
#
#         HI_INC_RPY_3YR_RT_SUPP  NONCOM_RPY_3YR_RT_SUPP  \
# UNITID
# 100654                0.291972                0.293883
# 100663                0.777123                0.637756
# 100690                0.740380                0.563934
# 100706                0.818622                0.650204
# 100724                0.183333                0.228715
#
#         FIRSTGEN_RPY_3YR_RT_SUPP  PCT_LIBERAL_ARTS  PCT_VOCATIONAL  \
# UNITID
# 100654                  0.342166            0.5346    6.290000e-02
# 100663                  0.716461            0.4379    4.024558e-18
# 100690                  0.580768            0.6301    4.024558e-18
# 100706                  0.746823            0.2764    4.024558e-18
# 100724                  0.219090            0.5449    4.024558e-18
#
#         PCT_RELIGIOUS      COST  PCT_PROFESSIONAL
# UNITID
# 100654   1.390554e-16  0.191513           0.20370
# 100663   9.500000e-03  0.208693           0.29025
# 100690   2.603000e-01  0.088812           0.05480
# 100706   8.200000e-03  0.213619           0.35760
# 100724   1.390554e-16  0.168317           0.28665
#
# [5 rows x 56 columns]

# %% [markdown]
# # Compute the cosine similarity:
#
# Import from scikit-learn and let it do all the work :-)

# %%
from sklearn.metrics.pairwise import cosine_similarity

c = cosine_similarity(rescaled, rescaled)

# %% [markdown]
# That returns a square numpy array with the similarity of each school to every other.  Now we need to pipe it back into a dataframe so we can keep everything indexed:

# %%
cosim = pd.DataFrame(c, index=data.index, columns=data.index)
cosim['INSTNM'] = data.INSTNM
cosim['ZIP'] = data.ZIP

# %% [markdown]
# Rearrange the columns so INSTNM and ZIP are at the front:

# %%
cols = cosim.columns.tolist()
cosim = cosim[cols[-2:]+cols[:-2]]

cosim.head()
# Out:
# UNITID                               INSTNM         ZIP    100654    100663  \
# UNITID
# 100654             Alabama A & M University       35762  1.000000  0.786330
# 100663  University of Alabama at Birmingham  35294-0110  0.786330  1.000000
# 100690                   Amridge University  36117-3553  0.760208  0.915292
# 100706  University of Alabama in Huntsville       35899  0.747198  0.988881
# 100724             Alabama State University  36104-0271  0.903731  0.681336
#
# UNITID    100690    100706    100724    100751    100812    100830    ...     \
# UNITID                                                                ...
# 100654  0.760208  0.747198  0.903731  0.723629  0.717689  0.799929    ...
# 100663  0.915292  0.988881  0.681336  0.983041  0.936378  0.948351    ...
# 100690  1.000000  0.886403  0.709962  0.885201  0.903969  0.909588    ...
# 100706  0.886403  1.000000  0.632737  0.981303  0.945429  0.934215    ...
# 100724  0.709962  0.632737  1.000000  0.618028  0.642089  0.705760    ...
#
# UNITID  45891904  45891905  45891906  45891907  45896401  45896402  45897301  \
# UNITID
# 100654  0.658874  0.658874  0.658874  0.658874  0.658874  0.658874  0.658874
# 100663  0.751214  0.751214  0.751214  0.751214  0.751214  0.751214  0.751214
# 100690  0.844421  0.844421  0.844421  0.844421  0.844421  0.844421  0.844421
# 100706  0.759726  0.759726  0.759726  0.759726  0.759726  0.759726  0.759726
# 100724  0.664862  0.664862  0.664862  0.664862  0.664862  0.664862  0.664862
#
# UNITID  45897302  45897303  45897304
# UNITID
# 100654  0.658874  0.658874  0.658874
# 100663  0.751214  0.751214  0.751214
# 100690  0.844421  0.844421  0.844421
# 100706  0.759726  0.759726  0.759726
# 100724  0.664862  0.664862  0.664862
#
# [5 rows x 2475 columns]

# %% [markdown]
# # Look at a few examples:

# %%
cosim[cosim.INSTNM.str.contains('Harvard')]['INSTNM']
# Out:
# UNITID
# 166027    Harvard University
# Name: INSTNM, dtype: object

# %%
cosim[['INSTNM', 166027]].sort_values(166027, ascending=False).head(15)
# Out:
# UNITID                                       INSTNM    166027
# UNITID
# 166027                           Harvard University  1.000000
# 130794                              Yale University  0.990052
# 243744                          Stanford University  0.987735
# 190150  Columbia University in the City of New York  0.984804
# 215062                   University of Pennsylvania  0.983386
# 198419                              Duke University  0.981275
# 131496                        Georgetown University  0.979903
# 144050                        University of Chicago  0.979379
# 147767                      Northwestern University  0.978448
# 190415                           Cornell University  0.978352
# 186131                         Princeton University  0.978056
# 217156                             Brown University  0.977840
# 166683        Massachusetts Institute of Technology  0.977373
# 221999                        Vanderbilt University  0.976229
# 182670                            Dartmouth College  0.976186

# %%
cosim[cosim.INSTNM.str.contains('Truman')]['INSTNM']
# Out:
# UNITID
# 178615    Truman State University
# Name: INSTNM, dtype: object

# %%
cosim[['INSTNM', 178615]].sort_values(178615, ascending=False).head(15)
# Out:
# UNITID                                                              INSTNM  \
# UNITID
# 178615                                             Truman State University
# 197869                                        Appalachian State University
# 207388                               Oklahoma State University-Main Campus
# 176017                                           University of Mississippi
# 176080                                        Mississippi State University
# 23693902                               Washington State University-Spokane
# 139861                                Georgia College and State University
# 236939                                         Washington State University
# 174251                                      University of Minnesota-Morris
# 163912                                       St Mary's College of Maryland
# 130943                                              University of Delaware
# 196185                                                        SUNY Oneonta
# 243780                                       Purdue University-Main Campus
# 159391    Louisiana State University and Agricultural & Mechanical College
# 196194                                              SUNY College at Oswego
#
# UNITID      178615
# UNITID
# 178615    1.000000
# 197869    0.993833
# 207388    0.992497
# 176017    0.991404
# 176080    0.989908
# 23693902  0.988417
# 139861    0.988400
# 236939    0.986461
# 174251    0.986216
# 163912    0.985581
# 130943    0.985352
# 196185    0.985295
# 243780    0.985276
# 159391    0.984867
# 196194    0.984805

# %%
cosim[cosim.INSTNM.str.contains('University of Utah')]['INSTNM']
# Out:
# UNITID
# 230764    University of Utah
# Name: INSTNM, dtype: object

# %%
cosim[['INSTNM', 230764]].sort_values(230764, ascending=False).head(15)
# Out:
# UNITID                                  INSTNM    230764
# UNITID
# 230764                      University of Utah  1.000000
# 209542                 Oregon State University  0.991880
# 155317                    University of Kansas  0.991545
# 182290               University of Nevada-Reno  0.991231
# 181464          University of Nebraska-Lincoln  0.990149
# 200280              University of North Dakota  0.990056
# 106397                  University of Arkansas  0.989940
# 126818  Colorado State University-Fort Collins  0.989721
# 136172             University of North Florida  0.989581
# 157085                  University of Kentucky  0.989494
# 229115                   Texas Tech University  0.989383
# 155399                 Kansas State University  0.989355
# 221759   The University of Tennessee-Knoxville  0.988533
# 179566   Missouri State University-Springfield  0.988515
# 198464                East Carolina University  0.988363

# %%
cosim[cosim.INSTNM.str.contains('University of Texas at Austin')]['INSTNM']
# Out:
# UNITID
# 228778    The University of Texas at Austin
# Name: INSTNM, dtype: object

# %%
cosim[['INSTNM', 228778]].sort_values(228778, ascending=False).head(15)
# Out:
# UNITID                                               INSTNM    228778
# UNITID
# 228778                    The University of Texas at Austin  1.000000
# 134130                                University of Florida  0.994270
# 170976                     University of Michigan-Ann Arbor  0.994043
# 234076                   University of Virginia-Main Campus  0.992805
# 236948              University of Washington-Seattle Campus  0.992653
# 228723               Texas A & M University-College Station  0.991997
# 134097                             Florida State University  0.991862
# 196079                                   SUNY at Binghamton  0.991292
# 110680                   University of California-San Diego  0.991271
# 199120          University of North Carolina at Chapel Hill  0.991104
# 186380                     Rutgers University-New Brunswick  0.990792
# 233921  Virginia Polytechnic Institute and State University  0.989922
# 174066                  University of Minnesota-Twin Cities  0.989382
# 240444                      University of Wisconsin-Madison  0.988912
# 129020                            University of Connecticut  0.988812

# %%
cosim[cosim.INSTNM.str.contains('California Institute of Technology')]['INSTNM']
# Out:
# UNITID
# 110404    California Institute of Technology
# Name: INSTNM, dtype: object

# %%
cosim[['INSTNM', 110404]].sort_values(110404, ascending=False).head(15)
# Out:
# UNITID                                 INSTNM    110404
# UNITID
# 110404     California Institute of Technology  1.000000
# 166683  Massachusetts Institute of Technology  0.972223
# 227757                        Rice University  0.971557
# 211440             Carnegie Mellon University  0.971167
# 115409                    Harvey Mudd College  0.970876
# 186131                   Princeton University  0.966013
# 167358                Northeastern University  0.965728
# 110635      University of California-Berkeley  0.965042
# 112260              Claremont McKenna College  0.964793
# 207971                    University of Tulsa  0.964416
# 243744                    Stanford University  0.963771
# 147767                Northwestern University  0.963155
# 190415                     Cornell University  0.963096
# 164465                        Amherst College  0.962345
# 121345                         Pomona College  0.962272

# %% [markdown]
# ## Looks like this is doing a decent job.  Not amazing, as there are some possible oddities (U. of Tulsa is the 10th most similar to Caltech!?!?), but pretty decent.
#
# Maybe those two really are quite similar, and Tulsa just gets a bad rap ;-)

# %% [markdown]
# # Finally, save to csv.

# %%
cosim.to_csv('data/similarity_index.csv')

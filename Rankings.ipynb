# %% [markdown]
# # Ranking schools by similarity:
#
# This notebook takes the similarity matrix, and for each school, finds the 15 most similar schools, saving the results to disk.

# %%
import pandas as pd

# %% [markdown]
#  Load the similarity matrix:

# %%
cosim = pd.read_csv('data/similarity_index.csv', index_col='UNITID')
cosim.head()
# Out:
#                                      INSTNM         ZIP    100654    100663  \
# UNITID
# 100654             Alabama A & M University       35762  1.000000  0.645446
# 100663  University of Alabama at Birmingham  35294-0110  0.645446  1.000000
# 100690                   Amridge University  36117-3553  0.559181  0.683236
# 100706  University of Alabama in Huntsville       35899  0.617786  0.927120
# 100724             Alabama State University  36104-0271  0.852245  0.555639
#
#           100690    100706    100724    100751    100812    100830    ...     \
# UNITID                                                                ...
# 100654  0.559181  0.617786  0.852245  0.535816  0.520810  0.718865    ...
# 100663  0.683236  0.927120  0.555639  0.736936  0.700375  0.825310    ...
# 100690  1.000000  0.659358  0.489259  0.600211  0.603639  0.663921    ...
# 100706  0.659358  1.000000  0.525419  0.730869  0.701689  0.885037    ...
# 100724  0.489259  0.525419  1.000000  0.438288  0.450393  0.648715    ...
#
#         45891904  45891905  45891906  45891907  45896401  45896402  45897301  \
# UNITID
# 100654  0.397937  0.482052  0.482052  0.482052  0.482052  0.482052  0.480283
# 100663  0.572220  0.568836  0.568836  0.568836  0.568836  0.568836  0.568492
# 100690  0.501795  0.498200  0.498200  0.498200  0.498200  0.498200  0.497286
# 100706  0.496750  0.493836  0.493836  0.493836  0.493836  0.493836  0.493430
# 100724  0.353488  0.452585  0.452585  0.452585  0.452585  0.452585  0.450919
#
#         45897302  45897303  45897304
# UNITID
# 100654  0.480283  0.482052  0.482052
# 100663  0.568492  0.568836  0.568836
# 100690  0.497286  0.498200  0.498200
# 100706  0.493430  0.493836  0.493836
# 100724  0.450919  0.452585  0.452585
#
# [5 rows x 2475 columns]

# %% [markdown]
# Set up a dataframe for the rankings:

# %%
rankings = pd.DataFrame(index=cosim.index, columns=['Similar School {}'.format(i) for i in range(1,16)])
rankings.head()
# Out:
#        Similar School 1 Similar School 2 Similar School 3 Similar School 4  \
# UNITID
# 100654              NaN              NaN              NaN              NaN
# 100663              NaN              NaN              NaN              NaN
# 100690              NaN              NaN              NaN              NaN
# 100706              NaN              NaN              NaN              NaN
# 100724              NaN              NaN              NaN              NaN
#
#        Similar School 5 Similar School 6 Similar School 7 Similar School 8  \
# UNITID
# 100654              NaN              NaN              NaN              NaN
# 100663              NaN              NaN              NaN              NaN
# 100690              NaN              NaN              NaN              NaN
# 100706              NaN              NaN              NaN              NaN
# 100724              NaN              NaN              NaN              NaN
#
#        Similar School 9 Similar School 10 Similar School 11 Similar School 12  \
# UNITID
# 100654              NaN               NaN               NaN               NaN
# 100663              NaN               NaN               NaN               NaN
# 100690              NaN               NaN               NaN               NaN
# 100706              NaN               NaN               NaN               NaN
# 100724              NaN               NaN               NaN               NaN
#
#        Similar School 13 Similar School 14 Similar School 15
# UNITID
# 100654               NaN               NaN               NaN
# 100663               NaN               NaN               NaN
# 100690               NaN               NaN               NaN
# 100706               NaN               NaN               NaN
# 100724               NaN               NaN               NaN

# %% [markdown]
# For each school (row) in the ranking index, select that column from the similarity index, sort by highest value (most similar), and enter the corresponding school id's in that row:

# %%
for id in rankings.index:
    rankings.loc[id] = cosim[str(id)].sort_values(ascending=False)[1:16].index

# %%
rankings.head()
# Out:
#         Similar School 1  Similar School 2  Similar School 3  \
# UNITID
# 100654            199157            232937            160621
# 100663            230764            100706            234030
# 100690            113704            230825            388520
# 100706            100663            230764            226833
# 100724            160621            199157            232937
#
#         Similar School 4  Similar School 5  Similar School 6  \
# UNITID
# 100654            100724            227526            199999
# 100663            104151            134097            139940
# 100690            439446            475273            198747
# 100706            229179            138789            100830
# 100724            140960            227526            100654
#
#         Similar School 7  Similar School 8  Similar School 9  \
# UNITID
# 100654            213598            133650            175856
# 100663            209551            132903            228787
# 100690            155636            420246            443049
# 100706            219602            221759            178396
# 100724            175856            199999            138716
#
#         Similar School 10  Similar School 11  Similar School 12  \
# UNITID
# 100654             130934             234155             140960
# 100663             137351             227216             225511
# 100690             444990             206154             133492
# 100706             240444             126818             134097
# 100724             159009             199102             163453
#
#         Similar School 13  Similar School 14  Similar School 15
# UNITID
# 100654             218733             163338             139719
# 100663             102094             142115             166708
# 100690             175980             236328             199272
# 100706             228787             218663             234030
# 100724             213598             133650             106412

# %% [markdown]
# Sanity check (Harvard):

# %%
cosim[['INSTNM', '166027']].sort_values('166027', ascending=False).head(16)
# Out:
#                                              INSTNM    166027
# UNITID
# 166027                           Harvard University  1.000000
# 130794                              Yale University  0.991754
# 198419                              Duke University  0.984593
# 166683        Massachusetts Institute of Technology  0.981545
# 243744                          Stanford University  0.951910
# 190150  Columbia University in the City of New York  0.946907
# 215062                   University of Pennsylvania  0.946676
# 131496                        Georgetown University  0.943269
# 144050                        University of Chicago  0.943169
# 147767                      Northwestern University  0.942208
# 190415                           Cornell University  0.941480
# 217156                             Brown University  0.941450
# 221999                        Vanderbilt University  0.939526
# 179867            Washington University in St Louis  0.938230
# 139658                             Emory University  0.935496
# 162928                     Johns Hopkins University  0.931006

# %%
rankings.loc[166027]
# Out:
# Similar School 1     130794
# Similar School 2     198419
# Similar School 3     166683
# Similar School 4     243744
# Similar School 5     190150
# Similar School 6     215062
# Similar School 7     131496
# Similar School 8     144050
# Similar School 9     147767
# Similar School 10    190415
# Similar School 11    217156
# Similar School 12    221999
# Similar School 13    179867
# Similar School 14    139658
# Similar School 15    162928
# Name: 166027, dtype: int64

# %% [markdown]
# Everything looks good!  Save to disk:

# %%
rankings.to_csv('data/similarity_rankings.csv')

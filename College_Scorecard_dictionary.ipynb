# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# Out:
# /home/jhummel/anaconda/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
pd.set_option("display.max_rows",100)
pd.get_option("display.max_columns")

pd.set_option('max_colwidth', 100)

# %%
df_dict = pd.read_csv('CollegeScorecardDataDictionary-09-08-2015.csv')
df_dict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1953 entries, 0 to 1952
# Data columns (total 9 columns):
# NAME OF DATA ELEMENT       1720 non-null object
# dev-category               1848 non-null object
# developer-friendly name    1720 non-null object
# API data type              1720 non-null object
# VARIABLE NAME              1720 non-null object
# VALUE                      289 non-null object
# LABEL                      297 non-null object
# SOURCE                     1720 non-null object
# NOTES                      44 non-null object
# dtypes: object(9)
# memory usage: 137.4+ KB

# %%
df_dict.columns
# Out:
# Index(['NAME OF DATA ELEMENT', 'dev-category', 'developer-friendly name',
#        'API data type', 'VARIABLE NAME', 'VALUE', 'LABEL', 'SOURCE', 'NOTES'],
#       dtype='object')

# %%
df_dict.set_index('VARIABLE NAME', inplace=True)

# %%
df_dict
# Out:
#                                                                                                             NAME OF DATA ELEMENT  \
# VARIABLE NAME
# UNITID                                                                                                   Unit ID for institution
# OPEID                                                                                             8-digit OPE ID for institution
# opeid6                                                                                            6-digit OPE ID for institution
# INSTNM                                                                                                          Institution name
# CITY                                                                                                                        City
# STABBR                                                                                                            State postcode
# ZIP                                                                                                                     ZIP code
# AccredAgency                                                                                          Accreditor for institution
# INSTURL                                                                                           URL for institution's homepage
# NPCURL                                                                                URL for institution's net price calculator
# sch_deg                                                                           Predominant degree awarded (recoded 0s and 4s)
# main                                                                                                        Flag for main campus
# NaN                                                                                                                          NaN
# NUMBRANCH                                                                                              Number of branch campuses
# PREDDEG                      Predominant degree awarded\r\n0        Not classified\r\n1        Predominantly certificate-degr...
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# HIGHDEG                      Highest degree awarded\r\n0        Non-degree-granting\r\n1        Certificate degree\r\n2      ...
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# CONTROL                                                                                                   Control of institution
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# st_fips                                                                                                      FIPS code for state
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# NaN                                                                                                                          NaN
# ...                                                                                                                          ...
# gt_25k_p6                                   Share of students earning over $25,000/year (threshold earnings) 6 years after entry
# mn_earn_wne_inc1_p6          Mean earnings of students working and not enrolled 6 years after entry in the lowest income tercile
# mn_earn_wne_inc2_p6          Mean earnings of students working and not enrolled 6 years after entry in the middle income tercile
# mn_earn_wne_inc3_p6          Mean earnings of students working and not enrolled 6 years after entry in the highest income ter...
# mn_earn_wne_indep0_inc1_p6   Mean earnings of dependent students working and not enrolled 6 years after entry in the lowest i...
# mn_earn_wne_indep0_p6                           Mean earnings of dependent students working and not enrolled 6 years after entry
# mn_earn_wne_indep1_p6                         Mean earnings of independent students working and not enrolled 6 years after entry
# mn_earn_wne_male0_p6                               Mean earnings of female students working and not enrolled 6 years after entry
# mn_earn_wne_male1_p6                                 Mean earnings of male students working and not enrolled 6 years after entry
# count_nwne_p7                                                Number of students not working and not enrolled 7 years after entry
# count_wne_p7                                                     Number of students working and not enrolled 7 years after entry
# mn_earn_wne_p7                                            Mean earnings of students working and not enrolled 7 years after entry
# sd_earn_wne_p7                           Standard deviation of earnings of students working and not enrolled 7 years after entry
# gt_25k_p7                                   Share of students earning over $25,000/year (threshold earnings) 7 years after entry
# count_nwne_p8                                                Number of students not working and not enrolled 8 years after entry
# count_wne_p8                                                     Number of students working and not enrolled 8 years after entry
# mn_earn_wne_p8                                            Mean earnings of students working and not enrolled 8 years after entry
# md_earn_wne_p8                                          Median earnings of students working and not enrolled 8 years after entry
# pct10_earn_wne_p8                           10th percentile of earnings of students working and not enrolled 8 years after entry
# pct25_earn_wne_p8                           25th percentile of earnings of students working and not enrolled 8 years after entry
# pct75_earn_wne_p8                           75th percentile of earnings of students working and not enrolled 8 years after entry
# pct90_earn_wne_p8                           90th percentile of earnings of students working and not enrolled 8 years after entry
# sd_earn_wne_p8                           Standard deviation of earnings of students working and not enrolled 8 years after entry
# gt_25k_p8                                   Share of students earning over $25,000/year (threshold earnings) 8 years after entry
# count_nwne_p9                                                Number of students not working and not enrolled 9 years after entry
# count_wne_p9                                                     Number of students working and not enrolled 9 years after entry
# mn_earn_wne_p9                                            Mean earnings of students working and not enrolled 9 years after entry
# sd_earn_wne_p9                           Standard deviation of earnings of students working and not enrolled 9 years after entry
# gt_25k_p9                                   Share of students earning over $25,000/year (threshold earnings) 9 years after entry
# DEBT_MDN_SUPP                                                                                   Median debt, suppressed for n=30
# GRAD_DEBT_MDN_SUPP                                                                Median debt of completers, suppressed for n=30
# GRAD_DEBT_MDN10YR_SUPP                      Median debt of completers expressed in 10-year monthly payments, suppressed for n=30
# RPY_3YR_RT_SUPP                                                                       3-year repayment rate, suppressed for n=30
# LO_INC_RPY_3YR_RT_SUPP       3-year repayment rate for low-income (less than $30,000 in nominal family income) students, supp...
# MD_INC_RPY_3YR_RT_SUPP       3-year repayment rate for middle-income (between $30,000 and $75,000 in nominal family income) s...
# HI_INC_RPY_3YR_RT_SUPP       3-year repayment rate for high-income (above $75,000 in nominal family income) students, suppres...
# COMPL_RPY_3YR_RT_SUPP                                                  3-year repayment rate for completers, suppressed for n=30
# NONCOM_RPY_3YR_RT_SUPP                                             3-year repayment rate for non-completers, suppressed for n=30
# DEP_RPY_3YR_RT_SUPP                                            3-year repayment rate for dependent students, suppressed for n=30
# IND_RPY_3YR_RT_SUPP                                          3-year repayment rate for independent students, suppressed for n=30
# PELL_RPY_3YR_RT_SUPP                                                3-year repayment rate for Pell students, suppressed for n=30
# NOPELL_RPY_3YR_RT_SUPP                                           3-year repayment rate for no-Pell students, suppressed for n=30
# FEMALE_RPY_3YR_RT_SUPP                                            3-year repayment rate for female students, suppressed for n=30
# MALE_RPY_3YR_RT_SUPP                                                3-year repayment rate for male students, suppressed for n=30
# FIRSTGEN_RPY_3YR_RT_SUPP                                3-year repayment rate for first-generation students, suppressed for n=30
# NOTFIRSTGEN_RPY_3YR_RT_SUPP                         3-year repayment rate for non-first-generation students, suppressed for n=30
# C150_L4_POOLED_SUPP          150% completion rate for less-than-four-year institutions, pooled in two-year rolling averages a...
# C150_4_POOLED_SUPP           150% completion rate for four-year institutions, pooled in two-year rolling averages and suppres...
# C200_L4_POOLED_SUPP          200% completion rate for less-than-four-year institutions, pooled in two-year rolling averages a...
# C200_4_POOLED_SUPP           200% completion rate for four-year institutions, pooled in two-year rolling averages and suppres...
#
#                             dev-category  \
# VARIABLE NAME
# UNITID                              root
# OPEID                               root
# opeid6                              root
# INSTNM                            school
# CITY                              school
# STABBR                            school
# ZIP                               school
# AccredAgency                      school
# INSTURL                           school
# NPCURL                            school
# sch_deg                           school
# main                              school
# NaN                               school
# NUMBRANCH                         school
# PREDDEG                           school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# HIGHDEG                           school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# CONTROL                           school
# NaN                               school
# NaN                               school
# st_fips                           school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# NaN                               school
# ...                                  ...
# gt_25k_p6                       earnings
# mn_earn_wne_inc1_p6             earnings
# mn_earn_wne_inc2_p6             earnings
# mn_earn_wne_inc3_p6             earnings
# mn_earn_wne_indep0_inc1_p6      earnings
# mn_earn_wne_indep0_p6           earnings
# mn_earn_wne_indep1_p6           earnings
# mn_earn_wne_male0_p6            earnings
# mn_earn_wne_male1_p6            earnings
# count_nwne_p7                   earnings
# count_wne_p7                    earnings
# mn_earn_wne_p7                  earnings
# sd_earn_wne_p7                  earnings
# gt_25k_p7                       earnings
# count_nwne_p8                   earnings
# count_wne_p8                    earnings
# mn_earn_wne_p8                  earnings
# md_earn_wne_p8                  earnings
# pct10_earn_wne_p8               earnings
# pct25_earn_wne_p8               earnings
# pct75_earn_wne_p8               earnings
# pct90_earn_wne_p8               earnings
# sd_earn_wne_p8                  earnings
# gt_25k_p8                       earnings
# count_nwne_p9                   earnings
# count_wne_p9                    earnings
# mn_earn_wne_p9                  earnings
# sd_earn_wne_p9                  earnings
# gt_25k_p9                       earnings
# DEBT_MDN_SUPP                        aid
# GRAD_DEBT_MDN_SUPP                   aid
# GRAD_DEBT_MDN10YR_SUPP               aid
# RPY_3YR_RT_SUPP                repayment
# LO_INC_RPY_3YR_RT_SUPP         repayment
# MD_INC_RPY_3YR_RT_SUPP         repayment
# HI_INC_RPY_3YR_RT_SUPP         repayment
# COMPL_RPY_3YR_RT_SUPP          repayment
# NONCOM_RPY_3YR_RT_SUPP         repayment
# DEP_RPY_3YR_RT_SUPP            repayment
# IND_RPY_3YR_RT_SUPP            repayment
# PELL_RPY_3YR_RT_SUPP           repayment
# NOPELL_RPY_3YR_RT_SUPP         repayment
# FEMALE_RPY_3YR_RT_SUPP         repayment
# MALE_RPY_3YR_RT_SUPP           repayment
# FIRSTGEN_RPY_3YR_RT_SUPP       repayment
# NOTFIRSTGEN_RPY_3YR_RT_SUPP    repayment
# C150_L4_POOLED_SUPP           completion
# C150_4_POOLED_SUPP            completion
# C200_L4_POOLED_SUPP           completion
# C200_4_POOLED_SUPP            completion
#
#                                                                        developer-friendly name  \
# VARIABLE NAME
# UNITID                                                                                      id
# OPEID                                                                                  ope8_id
# opeid6                                                                                 ope6_id
# INSTNM                                                                                    name
# CITY                                                                                      city
# STABBR                                                                                   state
# ZIP                                                                                        zip
# AccredAgency                                                                        accreditor
# INSTURL                                                                             school_url
# NPCURL                                                                    price_calculator_url
# sch_deg                                                    degrees_awarded.predominant_recoded
# main                                                                               main_campus
# NaN                                                                                        NaN
# NUMBRANCH                                                                             branches
# PREDDEG                                                            degrees_awarded.predominant
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# HIGHDEG                                                                degrees_awarded.highest
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# CONTROL                                                                              ownership
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# st_fips                                                                             state_fips
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# NaN                                                                                        NaN
# ...                                                                                        ...
# gt_25k_p6                                         6_yrs_after_entry.percent_greater_than_25000
# mn_earn_wne_inc1_p6                             6_yrs_after_entry.mean_earnings.lowest_tercile
# mn_earn_wne_inc2_p6                             6_yrs_after_entry.mean_earnings.middle_tercile
# mn_earn_wne_inc3_p6                            6_yrs_after_entry.mean_earnings.highest_tercile
# mn_earn_wne_indep0_inc1_p6   6_yrs_after_entry.mean_earnings.dependent_students_lowest_tercile
# mn_earn_wne_indep0_p6                       6_yrs_after_entry.mean_earnings.dependent_students
# mn_earn_wne_indep1_p6                     6_yrs_after_entry.mean_earnings.independent_students
# mn_earn_wne_male0_p6                           6_yrs_after_entry.mean_earnings.female_students
# mn_earn_wne_male1_p6                             6_yrs_after_entry.mean_earnings.male_students
# count_nwne_p7                                       7_yrs_after_entry.not_working_not_enrolled
# count_wne_p7                                            7_yrs_after_entry.working_not_enrolled
# mn_earn_wne_p7                                                 7_yrs_after_entry.mean_earnings
# sd_earn_wne_p7                                                       7_yrs_after_entry.std_dev
# gt_25k_p7                                         7_yrs_after_entry.percent_greater_than_25000
# count_nwne_p8                                       8_yrs_after_entry.not_working_not_enrolled
# count_wne_p8                                            8_yrs_after_entry.working_not_enrolled
# mn_earn_wne_p8                                                 8_yrs_after_entry.mean_earnings
# md_earn_wne_p8                                               8_yrs_after_entry.median_earnings
# pct10_earn_wne_p8                                   8_yrs_after_entry.10th_percentile_earnings
# pct25_earn_wne_p8                                   8_yrs_after_entry.25th_percentile_earnings
# pct75_earn_wne_p8                                   8_yrs_after_entry.75th_percentile_earnings
# pct90_earn_wne_p8                                   8_yrs_after_entry.90th_percentile_earnings
# sd_earn_wne_p8                                                 8_yrs_after_entry.std_deviation
# gt_25k_p8                                         8_yrs_after_entry.percent_greater_than_25000
# count_nwne_p9                                       9_yrs_after_entry.not_working_not_enrolled
# count_wne_p9                                            9_yrs_after_entry.working_not_enrolled
# mn_earn_wne_p9                                                 9_yrs_after_entry.mean_earnings
# sd_earn_wne_p9                                                 9_yrs_after_entry.std_deviation
# gt_25k_p9                                         9_yrs_after_entry.percent_greater_than_25000
# DEBT_MDN_SUPP                                                   median_debt_suppressed.overall
# GRAD_DEBT_MDN_SUPP                                   median_debt_suppressed.completers.overall
# GRAD_DEBT_MDN10YR_SUPP                      median_debt_suppressed.completers.monthly_payments
# RPY_3YR_RT_SUPP                                              3_yr_repayment_suppressed.overall
# LO_INC_RPY_3YR_RT_SUPP                             3_yr_repayment_suppressed.income.low_income
# MD_INC_RPY_3YR_RT_SUPP                          3_yr_repayment_suppressed.income.middle_income
# HI_INC_RPY_3YR_RT_SUPP                            3_yr_repayment_suppressed.income.high_income
# COMPL_RPY_3YR_RT_SUPP                                     3_yr_repayment_suppressed.completers
# NONCOM_RPY_3YR_RT_SUPP                                3_yr_repayment_suppressed.non_completers
# DEP_RPY_3YR_RT_SUPP                               3_yr_repayment_suppressed.dependent_students
# IND_RPY_3YR_RT_SUPP                             3_yr_repayment_suppressed.independent_students
# PELL_RPY_3YR_RT_SUPP                                      3_yr_repayment_suppressed.pell_grant
# NOPELL_RPY_3YR_RT_SUPP                                 3_yr_repayment_suppressed.no_pell_grant
# FEMALE_RPY_3YR_RT_SUPP                               3_yr_repayment_suppressed.female_students
# MALE_RPY_3YR_RT_SUPP                                   3_yr_repayment_suppressed.male_students
# FIRSTGEN_RPY_3YR_RT_SUPP                   3_yr_repayment_suppressed.first_generation_students
# NOTFIRSTGEN_RPY_3YR_RT_SUPP            3_yr_repayment_suppressed.non_first_generation_students
# C150_L4_POOLED_SUPP                                    rate_suppressed.lt_four_year_150percent
# C150_4_POOLED_SUPP                                                   rate_suppressed.four_year
# C200_L4_POOLED_SUPP                                               rate_suppressed.lt_four_year
# C200_4_POOLED_SUPP                                        rate_suppressed.four_year_200percent
#
#                             API data type VALUE  \
# VARIABLE NAME
# UNITID                            integer   NaN
# OPEID                             integer   NaN
# opeid6                            integer   NaN
# INSTNM                       autocomplete   NaN
# CITY                         autocomplete   NaN
# STABBR                             string   NaN
# ZIP                               integer   NaN
# AccredAgency                       string   NaN
# INSTURL                            string   NaN
# NPCURL                             string   NaN
# sch_deg                           integer
# main                              integer     0
# NaN                                   NaN     1
# NUMBRANCH                         integer   NaN
# PREDDEG                           integer     0
# NaN                                   NaN     1
# NaN                                   NaN     2
# NaN                                   NaN     3
# NaN                                   NaN     4
# HIGHDEG                           integer     0
# NaN                                   NaN     1
# NaN                                   NaN     2
# NaN                                   NaN     3
# NaN                                   NaN     4
# CONTROL                           integer     1
# NaN                                   NaN     2
# NaN                                   NaN     3
# st_fips                           integer     1
# NaN                                   NaN     2
# NaN                                   NaN     4
# NaN                                   NaN     5
# NaN                                   NaN     6
# NaN                                   NaN     8
# NaN                                   NaN     9
# NaN                                   NaN    10
# NaN                                   NaN    11
# NaN                                   NaN    12
# NaN                                   NaN    13
# NaN                                   NaN    15
# NaN                                   NaN    16
# NaN                                   NaN    17
# NaN                                   NaN    18
# NaN                                   NaN    19
# NaN                                   NaN    20
# NaN                                   NaN    21
# NaN                                   NaN    22
# NaN                                   NaN    23
# NaN                                   NaN    24
# NaN                                   NaN    25
# NaN                                   NaN    26
# ...                                   ...   ...
# gt_25k_p6                           float   NaN
# mn_earn_wne_inc1_p6                 float   NaN
# mn_earn_wne_inc2_p6                 float   NaN
# mn_earn_wne_inc3_p6                 float   NaN
# mn_earn_wne_indep0_inc1_p6          float   NaN
# mn_earn_wne_indep0_p6               float   NaN
# mn_earn_wne_indep1_p6               float   NaN
# mn_earn_wne_male0_p6                float   NaN
# mn_earn_wne_male1_p6                float   NaN
# count_nwne_p7                       float   NaN
# count_wne_p7                      integer   NaN
# mn_earn_wne_p7                      float   NaN
# sd_earn_wne_p7                      float   NaN
# gt_25k_p7                           float   NaN
# count_nwne_p8                     integer   NaN
# count_wne_p8                      integer   NaN
# mn_earn_wne_p8                      float   NaN
# md_earn_wne_p8                      float   NaN
# pct10_earn_wne_p8                 integer   NaN
# pct25_earn_wne_p8                 integer   NaN
# pct75_earn_wne_p8                 integer   NaN
# pct90_earn_wne_p8                 integer   NaN
# sd_earn_wne_p8                      float   NaN
# gt_25k_p8                           float   NaN
# count_nwne_p9                     integer   NaN
# count_wne_p9                      integer   NaN
# mn_earn_wne_p9                      float   NaN
# sd_earn_wne_p9                      float   NaN
# gt_25k_p9                           float   NaN
# DEBT_MDN_SUPP                       float   NaN
# GRAD_DEBT_MDN_SUPP                  float   NaN
# GRAD_DEBT_MDN10YR_SUPP              float   NaN
# RPY_3YR_RT_SUPP                     float   NaN
# LO_INC_RPY_3YR_RT_SUPP              float   NaN
# MD_INC_RPY_3YR_RT_SUPP              float   NaN
# HI_INC_RPY_3YR_RT_SUPP              float   NaN
# COMPL_RPY_3YR_RT_SUPP               float   NaN
# NONCOM_RPY_3YR_RT_SUPP              float   NaN
# DEP_RPY_3YR_RT_SUPP                 float   NaN
# IND_RPY_3YR_RT_SUPP                 float   NaN
# PELL_RPY_3YR_RT_SUPP                float   NaN
# NOPELL_RPY_3YR_RT_SUPP              float   NaN
# FEMALE_RPY_3YR_RT_SUPP              float   NaN
# MALE_RPY_3YR_RT_SUPP                float   NaN
# FIRSTGEN_RPY_3YR_RT_SUPP            float   NaN
# NOTFIRSTGEN_RPY_3YR_RT_SUPP         float   NaN
# C150_L4_POOLED_SUPP                 float   NaN
# C150_4_POOLED_SUPP                  float   NaN
# C200_L4_POOLED_SUPP                 float   NaN
# C200_4_POOLED_SUPP                  float   NaN
#
#                                                                  LABEL  \
# VARIABLE NAME
# UNITID                                                             NaN
# OPEID                                                              NaN
# opeid6                                                             NaN
# INSTNM                                                             NaN
# CITY                                                               NaN
# STABBR                                                             NaN
# ZIP                                                                NaN
# AccredAgency                                                       NaN
# INSTURL                                                            NaN
# NPCURL                                                             NaN
# sch_deg                                                            NaN
# main                                                   Not main campus
# NaN                                                        Main campus
# NUMBRANCH                                                          NaN
# PREDDEG                                                 Not classified
# NaN                          Predominantly certificate-degree granting
# NaN                          Predominantly associate's-degree granting
# NaN                           Predominantly bachelor's-degree granting
# NaN                                  Entirely graduate-degree granting
# HIGHDEG                                            Non-degree-granting
# NaN                                                 Certificate degree
# NaN                                                   Associate degree
# NaN                                                  Bachelor's degree
# NaN                                                    Graduate degree
# CONTROL                                                         Public
# NaN                                                  Private nonprofit
# NaN                                                 Private for-profit
# st_fips                                                        Alabama
# NaN                                                             Alaska
# NaN                                                            Arizona
# NaN                                                           Arkansas
# NaN                                                         California
# NaN                                                           Colorado
# NaN                                                        Connecticut
# NaN                                                           Delaware
# NaN                                               District of Columbia
# NaN                                                            Florida
# NaN                                                            Georgia
# NaN                                                             Hawaii
# NaN                                                              Idaho
# NaN                                                           Illinois
# NaN                                                            Indiana
# NaN                                                               Iowa
# NaN                                                             Kansas
# NaN                                                           Kentucky
# NaN                                                          Louisiana
# NaN                                                              Maine
# NaN                                                           Maryland
# NaN                                                      Massachusetts
# NaN                                                           Michigan
# ...                                                                ...
# gt_25k_p6                                                          NaN
# mn_earn_wne_inc1_p6                                                NaN
# mn_earn_wne_inc2_p6                                                NaN
# mn_earn_wne_inc3_p6                                                NaN
# mn_earn_wne_indep0_inc1_p6                                         NaN
# mn_earn_wne_indep0_p6                                              NaN
# mn_earn_wne_indep1_p6                                              NaN
# mn_earn_wne_male0_p6                                               NaN
# mn_earn_wne_male1_p6                                               NaN
# count_nwne_p7                                                      NaN
# count_wne_p7                                                       NaN
# mn_earn_wne_p7                                                     NaN
# sd_earn_wne_p7                                                     NaN
# gt_25k_p7                                                          NaN
# count_nwne_p8                                                      NaN
# count_wne_p8                                                       NaN
# mn_earn_wne_p8                                                     NaN
# md_earn_wne_p8                                                     NaN
# pct10_earn_wne_p8                                                  NaN
# pct25_earn_wne_p8                                                  NaN
# pct75_earn_wne_p8                                                  NaN
# pct90_earn_wne_p8                                                  NaN
# sd_earn_wne_p8                                                     NaN
# gt_25k_p8                                                          NaN
# count_nwne_p9                                                      NaN
# count_wne_p9                                                       NaN
# mn_earn_wne_p9                                                     NaN
# sd_earn_wne_p9                                                     NaN
# gt_25k_p9                                                          NaN
# DEBT_MDN_SUPP                                                      NaN
# GRAD_DEBT_MDN_SUPP                                                 NaN
# GRAD_DEBT_MDN10YR_SUPP                                             NaN
# RPY_3YR_RT_SUPP                                                    NaN
# LO_INC_RPY_3YR_RT_SUPP                                             NaN
# MD_INC_RPY_3YR_RT_SUPP                                             NaN
# HI_INC_RPY_3YR_RT_SUPP                                             NaN
# COMPL_RPY_3YR_RT_SUPP                                              NaN
# NONCOM_RPY_3YR_RT_SUPP                                             NaN
# DEP_RPY_3YR_RT_SUPP                                                NaN
# IND_RPY_3YR_RT_SUPP                                                NaN
# PELL_RPY_3YR_RT_SUPP                                               NaN
# NOPELL_RPY_3YR_RT_SUPP                                             NaN
# FEMALE_RPY_3YR_RT_SUPP                                             NaN
# MALE_RPY_3YR_RT_SUPP                                               NaN
# FIRSTGEN_RPY_3YR_RT_SUPP                                           NaN
# NOTFIRSTGEN_RPY_3YR_RT_SUPP                                        NaN
# C150_L4_POOLED_SUPP                                                NaN
# C150_4_POOLED_SUPP                                                 NaN
# C200_L4_POOLED_SUPP                                                NaN
# C200_4_POOLED_SUPP                                                 NaN
#
#                                   SOURCE  \
# VARIABLE NAME
# UNITID                             IPEDS
# OPEID                              IPEDS
# opeid6                             IPEDS
# INSTNM                             IPEDS
# CITY                               IPEDS
# STABBR                             IPEDS
# ZIP                                IPEDS
# AccredAgency                         OPE
# INSTURL                            IPEDS
# NPCURL                             IPEDS
# sch_deg                      IPEDS/NSLDS
# main                               IPEDS
# NaN                                  NaN
# NUMBRANCH                          IPEDS
# PREDDEG                            IPEDS
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# HIGHDEG                            IPEDS
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# CONTROL                            IPEDS
# NaN                                  NaN
# NaN                                  NaN
# st_fips                            IPEDS
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# NaN                                  NaN
# ...                                  ...
# gt_25k_p6                       Treasury
# mn_earn_wne_inc1_p6             Treasury
# mn_earn_wne_inc2_p6             Treasury
# mn_earn_wne_inc3_p6             Treasury
# mn_earn_wne_indep0_inc1_p6      Treasury
# mn_earn_wne_indep0_p6           Treasury
# mn_earn_wne_indep1_p6           Treasury
# mn_earn_wne_male0_p6            Treasury
# mn_earn_wne_male1_p6            Treasury
# count_nwne_p7                   Treasury
# count_wne_p7                    Treasury
# mn_earn_wne_p7                  Treasury
# sd_earn_wne_p7                  Treasury
# gt_25k_p7                       Treasury
# count_nwne_p8                   Treasury
# count_wne_p8                    Treasury
# mn_earn_wne_p8                  Treasury
# md_earn_wne_p8                  Treasury
# pct10_earn_wne_p8               Treasury
# pct25_earn_wne_p8               Treasury
# pct75_earn_wne_p8               Treasury
# pct90_earn_wne_p8               Treasury
# sd_earn_wne_p8                  Treasury
# gt_25k_p8                       Treasury
# count_nwne_p9                   Treasury
# count_wne_p9                    Treasury
# mn_earn_wne_p9                  Treasury
# sd_earn_wne_p9                  Treasury
# gt_25k_p9                       Treasury
# DEBT_MDN_SUPP                      NSLDS
# GRAD_DEBT_MDN_SUPP                 NSLDS
# GRAD_DEBT_MDN10YR_SUPP             NSLDS
# RPY_3YR_RT_SUPP                    NSLDS
# LO_INC_RPY_3YR_RT_SUPP             NSLDS
# MD_INC_RPY_3YR_RT_SUPP             NSLDS
# HI_INC_RPY_3YR_RT_SUPP             NSLDS
# COMPL_RPY_3YR_RT_SUPP              NSLDS
# NONCOM_RPY_3YR_RT_SUPP             NSLDS
# DEP_RPY_3YR_RT_SUPP                NSLDS
# IND_RPY_3YR_RT_SUPP                NSLDS
# PELL_RPY_3YR_RT_SUPP               NSLDS
# NOPELL_RPY_3YR_RT_SUPP             NSLDS
# FEMALE_RPY_3YR_RT_SUPP             NSLDS
# MALE_RPY_3YR_RT_SUPP               NSLDS
# FIRSTGEN_RPY_3YR_RT_SUPP           NSLDS
# NOTFIRSTGEN_RPY_3YR_RT_SUPP        NSLDS
# C150_L4_POOLED_SUPP                IPEDS
# C150_4_POOLED_SUPP                 IPEDS
# C200_L4_POOLED_SUPP                IPEDS
# C200_4_POOLED_SUPP                 IPEDS
#
#                                                                                                          NOTES
# VARIABLE NAME
# UNITID                                                                                                     NaN
# OPEID                                                                                                      NaN
# opeid6                                                                                                     NaN
# INSTNM                                                                                                     NaN
# CITY                                                                                                       NaN
# STABBR                                                                                                     NaN
# ZIP                                                                                                        NaN
# AccredAgency                                                                                               NaN
# INSTURL                                                                                                    NaN
# NPCURL                                                                                                     NaN
# sch_deg                      Missing values, 0s, and 4s from PREDDEG recoded according to NSLDS program length
# main                                                                                                       NaN
# NaN                                                                                                        NaN
# NUMBRANCH                                                                                                  NaN
# PREDDEG                                                                                                    NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# HIGHDEG                                                                                                    NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# CONTROL                                                                                                    NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# st_fips                                                                                                    NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# NaN                                                                                                        NaN
# ...                                                                                                        ...
# gt_25k_p6                                                                                                  NaN
# mn_earn_wne_inc1_p6                                                                                        NaN
# mn_earn_wne_inc2_p6                                                                                        NaN
# mn_earn_wne_inc3_p6                                                                                        NaN
# mn_earn_wne_indep0_inc1_p6                                                                                 NaN
# mn_earn_wne_indep0_p6                                                                                      NaN
# mn_earn_wne_indep1_p6                                                                                      NaN
# mn_earn_wne_male0_p6                                                                                       NaN
# mn_earn_wne_male1_p6                                                                                       NaN
# count_nwne_p7                                                                                              NaN
# count_wne_p7                                                                                               NaN
# mn_earn_wne_p7                                                                                             NaN
# sd_earn_wne_p7                                                                                             NaN
# gt_25k_p7                                                                                                  NaN
# count_nwne_p8                                                                                              NaN
# count_wne_p8                                                                                               NaN
# mn_earn_wne_p8                                                                                             NaN
# md_earn_wne_p8                                                                                             NaN
# pct10_earn_wne_p8                                                                                          NaN
# pct25_earn_wne_p8                                                                                          NaN
# pct75_earn_wne_p8                                                                                          NaN
# pct90_earn_wne_p8                                                                                          NaN
# sd_earn_wne_p8                                                                                             NaN
# gt_25k_p8                                                                                                  NaN
# count_nwne_p9                                                                                              NaN
# count_wne_p9                                                                                               NaN
# mn_earn_wne_p9                                                                                             NaN
# sd_earn_wne_p9                                                                                             NaN
# gt_25k_p9                                                                                                  NaN
# DEBT_MDN_SUPP                                                                                              NaN
# GRAD_DEBT_MDN_SUPP                                                                                         NaN
# GRAD_DEBT_MDN10YR_SUPP                                                                                     NaN
# RPY_3YR_RT_SUPP                                                                                            NaN
# LO_INC_RPY_3YR_RT_SUPP                                                                                     NaN
# MD_INC_RPY_3YR_RT_SUPP                                                                                     NaN
# HI_INC_RPY_3YR_RT_SUPP                                                                                     NaN
# COMPL_RPY_3YR_RT_SUPP                                                                                      NaN
# NONCOM_RPY_3YR_RT_SUPP                                                                                     NaN
# DEP_RPY_3YR_RT_SUPP                                                                                        NaN
# IND_RPY_3YR_RT_SUPP                                                                                        NaN
# PELL_RPY_3YR_RT_SUPP                                                                                       NaN
# NOPELL_RPY_3YR_RT_SUPP                                                                                     NaN
# FEMALE_RPY_3YR_RT_SUPP                                                                                     NaN
# MALE_RPY_3YR_RT_SUPP                                                                                       NaN
# FIRSTGEN_RPY_3YR_RT_SUPP                                                                                   NaN
# NOTFIRSTGEN_RPY_3YR_RT_SUPP                                                                                NaN
# C150_L4_POOLED_SUPP                                                                                        NaN
# C150_4_POOLED_SUPP                                                                                         NaN
# C200_L4_POOLED_SUPP                                                                                        NaN
# C200_4_POOLED_SUPP                                                                                         NaN
#
# [1953 rows x 8 columns]

# %%
dcat = df_dict.groupby('dev-category')

# %%
dcat.groups.keys()
# Out:
# dict_keys(['admissions', 'completion', 'cost', 'root', 'aid', 'repayment', 'academics', 'student', 'school', 'earnings'])

# %%
for key,df in dcat:
    vars()[key] = df
    print(key+':')
    print(df.info())
    print('\n')
# Out:
# academics:
# <class 'pandas.core.frame.DataFrame'>
# Index: 228 entries, PCIP01 to CIP54BACHL
# Data columns (total 8 columns):
# NAME OF DATA ELEMENT       228 non-null object
# dev-category               228 non-null object
# developer-friendly name    228 non-null object
# API data type              228 non-null object
# VALUE                      3 non-null object
# LABEL                      41 non-null object
# SOURCE                     228 non-null object
# NOTES                      0 non-null object
# dtypes: object(8)
# memory usage: 16.0+ KB
# None
#
#
# admissions:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, ADM_RATE to SAT_AVG_ALL
# Data columns (total 8 columns):
# NAME OF DATA ELEMENT       25 non-null object
# dev-category               25 non-null object
# developer-friendly name    25 non-null object
# API data type              25 non-null object
# VALUE                      0 non-null object
# LABEL                      0 non-null object
# SOURCE                     25 non-null object
# NOTES                      0 non-null object
# dtypes: object(8)
# memory usage: 1.8+ KB
# None
#
#
# aid:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, PCTPELL to GRAD_DEBT_MDN10YR_SUPP
# Data columns (total 8 columns):
# NAME OF DATA ELEMENT       40 non-null object
# dev-category               40 non-null object
# developer-friendly name    40 non-null object
# API data type              40 non-null object
# VALUE                      2 non-null object
# LABEL                      0 non-null object
# SOURCE                     40 non-null object
# NOTES                      2 non-null object
# dtypes: object(8)
# memory usage: 2.8+ KB
# None
#
#
# completion:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1023 entries, C150_4 to C200_4_POOLED_SUPP
# Data columns (total 8 columns):
# NAME OF DATA ELEMENT       1023 non-null object
# dev-category               1023 non-null object
# developer-friendly name    1023 non-null object
# API data type              1023 non-null object
# VALUE                      13 non-null object
# LABEL                      0 non-null object
# SOURCE                     1023 non-null object
# NOTES                      15 non-null object
# dtypes: object(8)
# memory usage: 71.9+ KB
# None
#
#
# cost:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65 entries, NPT4_PUB to TUITIONFEE_PROG
# Data columns (total 8 columns):
# NAME OF DATA ELEMENT       65 non-null object
# dev-category               65 non-null object
# developer-friendly name    65 non-null object
# API data type              65 non-null object
# VALUE                      0 non-null object
# LABEL                      0 non-null object
# SOURCE                     65 non-null object
# NOTES                      6 non-null object
# dtypes: object(8)
# memory usage: 4.6+ KB
# None
#
#
# earnings:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73 entries, count_ed to gt_25k_p9
# Data columns (total 8 columns):
# NAME OF DATA ELEMENT       73 non-null object
# dev-category               73 non-null object
# developer-friendly name    73 non-null object
# API data type              73 non-null object
# VALUE                      0 non-null object
# LABEL                      0 non-null object
# SOURCE                     73 non-null object
# NOTES                      0 non-null object
# dtypes: object(8)
# memory usage: 5.1+ KB
# None
#
#
# repayment:
# <class 'pandas.core.frame.DataFrame'>
# Index: 130 entries, CDR2 to NOTFIRSTGEN_RPY_3YR_RT_SUPP
# Data columns (total 8 columns):
# NAME OF DATA ELEMENT       130 non-null object
# dev-category               130 non-null object
# developer-friendly name    130 non-null object
# API data type              130 non-null object
# VALUE                      3 non-null object
# LABEL                      0 non-null object
# SOURCE                     130 non-null object
# NOTES                      3 non-null object
# dtypes: object(8)
# memory usage: 9.1+ KB
# None
#
#
# root:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, UNITID to LONGITUDE
# Data columns (total 8 columns):
# NAME OF DATA ELEMENT       5 non-null object
# dev-category               5 non-null object
# developer-friendly name    5 non-null object
# API data type              5 non-null object
# VALUE                      0 non-null object
# LABEL                      0 non-null object
# SOURCE                     5 non-null object
# NOTES                      0 non-null object
# dtypes: object(8)
# memory usage: 360.0+ bytes
# None
#
#
# school:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, INSTNM to HCM2
# Data columns (total 8 columns):
# NAME OF DATA ELEMENT       37 non-null object
# dev-category               165 non-null object
# developer-friendly name    37 non-null object
# API data type              37 non-null object
# VALUE                      156 non-null object
# LABEL                      151 non-null object
# SOURCE                     37 non-null object
# NOTES                      7 non-null object
# dtypes: object(8)
# memory usage: 11.6+ KB
# None
#
#
# student:
# <class 'pandas.core.frame.DataFrame'>
# Index: 94 entries, UGDS to fsend_5
# Data columns (total 8 columns):
# NAME OF DATA ELEMENT       94 non-null object
# dev-category               94 non-null object
# developer-friendly name    94 non-null object
# API data type              94 non-null object
# VALUE                      7 non-null object
# LABEL                      0 non-null object
# SOURCE                     94 non-null object
# NOTES                      11 non-null object
# dtypes: object(8)
# memory usage: 6.6+ KB
# None

# %%
earnings
# Out:
#                                                                                                             NAME OF DATA ELEMENT  \
# VARIABLE NAME
# count_ed                                                                                Count of students in the earnings cohort
# count_nwne_p10                                              Number of students not working and not enrolled 10 years after entry
# count_wne_p10                                                   Number of students working and not enrolled 10 years after entry
# mn_earn_wne_p10                                          Mean earnings of students working and not enrolled 10 years after entry
# md_earn_wne_p10                                        Median earnings of students working and not enrolled 10 years after entry
# pct10_earn_wne_p10                         10th percentile of earnings of students working and not enrolled 10 years after entry
# pct25_earn_wne_p10                         25th percentile of earnings of students working and not enrolled 10 years after entry
# pct75_earn_wne_p10                         75th percentile of earnings of students working and not enrolled 10 years after entry
# pct90_earn_wne_p10                         90th percentile of earnings of students working and not enrolled 10 years after entry
# sd_earn_wne_p10                         Standard deviation of earnings of students working and not enrolled 10 years after entry
# count_wne_inc1_p10                 Number of students working and not enrolled 10 years after entry in the lowest income tercile
# count_wne_inc2_p10                 Number of students working and not enrolled 10 years after entry in the middle income tercile
# count_wne_inc3_p10                Number of students working and not enrolled 10 years after entry in the highest income tercile
# count_wne_indep0_inc1_p10    Number of dependent students working and not enrolled 10 years after entry in the lowest income ...
# count_wne_indep0_p10                                  Number of dependent students working and not enrolled 10 years after entry
# count_wne_indep1_p10                                Number of independent students working and not enrolled 10 years after entry
# count_wne_male0_p10                                      Number of female students working and not enrolled 10 years after entry
# count_wne_male1_p10                                        Number of male students working and not enrolled 10 years after entry
# gt_25k_p10                                 Share of students earning over $25,000/year (threshold earnings) 10 years after entry
# mn_earn_wne_inc1_p10         Mean earnings of students working and not enrolled 10 years after entry in the lowest income ter...
# mn_earn_wne_inc2_p10         Mean earnings of students working and not enrolled 10 years after entry in the middle income ter...
# mn_earn_wne_inc3_p10         Mean earnings of students working and not enrolled 10 years after entry in the highest income te...
# mn_earn_wne_indep0_inc1_p10  Mean earnings of dependent students working and not enrolled 10 years after entry in the lowest ...
# mn_earn_wne_indep0_p10                         Mean earnings of dependent students working and not enrolled 10 years after entry
# mn_earn_wne_indep1_p10                       Mean earnings of independent students working and not enrolled 10 years after entry
# mn_earn_wne_male0_p10                             Mean earnings of female students working and not enrolled 10 years after entry
# mn_earn_wne_male1_p10                               Mean earnings of male students working and not enrolled 10 years after entry
# count_nwne_p6                                                Number of students not working and not enrolled 6 years after entry
# count_wne_p6                                                     Number of students working and not enrolled 6 years after entry
# mn_earn_wne_p6                                            Mean earnings of students working and not enrolled 6 years after entry
# md_earn_wne_p6                                          Median earnings of students working and not enrolled 6 years after entry
# pct10_earn_wne_p6                           10th percentile of earnings of students working and not enrolled 6 years after entry
# pct25_earn_wne_p6                           25th percentile of earnings of students working and not enrolled 6 years after entry
# pct75_earn_wne_p6                           75th percentile of earnings of students working and not enrolled 6 years after entry
# pct90_earn_wne_p6                           90th percentile of earnings of students working and not enrolled 6 years after entry
# sd_earn_wne_p6                           Standard deviation of earnings of students working and not enrolled 6 years after entry
# count_wne_inc1_p6                   Number of students working and not enrolled 6 years after entry in the lowest income tercile
# count_wne_inc2_p6                   Number of students working and not enrolled 6 years after entry in the middle income tercile
# count_wne_inc3_p6                  Number of students working and not enrolled 6 years after entry in the highest income tercile
# count_wne_indep0_inc1_p6     Number of dependent students working and not enrolled 6 years after entry in the lowest income t...
# count_wne_indep0_p6                                    Number of dependent students working and not enrolled 6 years after entry
# count_wne_indep1_p6                                  Number of independent students working and not enrolled 6 years after entry
# count_wne_male0_p6                                        Number of female students working and not enrolled 6 years after entry
# count_wne_male1_p6                                          Number of male students working and not enrolled 6 years after entry
# gt_25k_p6                                   Share of students earning over $25,000/year (threshold earnings) 6 years after entry
# mn_earn_wne_inc1_p6          Mean earnings of students working and not enrolled 6 years after entry in the lowest income tercile
# mn_earn_wne_inc2_p6          Mean earnings of students working and not enrolled 6 years after entry in the middle income tercile
# mn_earn_wne_inc3_p6          Mean earnings of students working and not enrolled 6 years after entry in the highest income ter...
# mn_earn_wne_indep0_inc1_p6   Mean earnings of dependent students working and not enrolled 6 years after entry in the lowest i...
# mn_earn_wne_indep0_p6                           Mean earnings of dependent students working and not enrolled 6 years after entry
# mn_earn_wne_indep1_p6                         Mean earnings of independent students working and not enrolled 6 years after entry
# mn_earn_wne_male0_p6                               Mean earnings of female students working and not enrolled 6 years after entry
# mn_earn_wne_male1_p6                                 Mean earnings of male students working and not enrolled 6 years after entry
# count_nwne_p7                                                Number of students not working and not enrolled 7 years after entry
# count_wne_p7                                                     Number of students working and not enrolled 7 years after entry
# mn_earn_wne_p7                                            Mean earnings of students working and not enrolled 7 years after entry
# sd_earn_wne_p7                           Standard deviation of earnings of students working and not enrolled 7 years after entry
# gt_25k_p7                                   Share of students earning over $25,000/year (threshold earnings) 7 years after entry
# count_nwne_p8                                                Number of students not working and not enrolled 8 years after entry
# count_wne_p8                                                     Number of students working and not enrolled 8 years after entry
# mn_earn_wne_p8                                            Mean earnings of students working and not enrolled 8 years after entry
# md_earn_wne_p8                                          Median earnings of students working and not enrolled 8 years after entry
# pct10_earn_wne_p8                           10th percentile of earnings of students working and not enrolled 8 years after entry
# pct25_earn_wne_p8                           25th percentile of earnings of students working and not enrolled 8 years after entry
# pct75_earn_wne_p8                           75th percentile of earnings of students working and not enrolled 8 years after entry
# pct90_earn_wne_p8                           90th percentile of earnings of students working and not enrolled 8 years after entry
# sd_earn_wne_p8                           Standard deviation of earnings of students working and not enrolled 8 years after entry
# gt_25k_p8                                   Share of students earning over $25,000/year (threshold earnings) 8 years after entry
# count_nwne_p9                                                Number of students not working and not enrolled 9 years after entry
# count_wne_p9                                                     Number of students working and not enrolled 9 years after entry
# mn_earn_wne_p9                                            Mean earnings of students working and not enrolled 9 years after entry
# sd_earn_wne_p9                           Standard deviation of earnings of students working and not enrolled 9 years after entry
# gt_25k_p9                                   Share of students earning over $25,000/year (threshold earnings) 9 years after entry
#
#                             dev-category  \
# VARIABLE NAME
# count_ed                        earnings
# count_nwne_p10                  earnings
# count_wne_p10                   earnings
# mn_earn_wne_p10                 earnings
# md_earn_wne_p10                 earnings
# pct10_earn_wne_p10              earnings
# pct25_earn_wne_p10              earnings
# pct75_earn_wne_p10              earnings
# pct90_earn_wne_p10              earnings
# sd_earn_wne_p10                 earnings
# count_wne_inc1_p10              earnings
# count_wne_inc2_p10              earnings
# count_wne_inc3_p10              earnings
# count_wne_indep0_inc1_p10       earnings
# count_wne_indep0_p10            earnings
# count_wne_indep1_p10            earnings
# count_wne_male0_p10             earnings
# count_wne_male1_p10             earnings
# gt_25k_p10                      earnings
# mn_earn_wne_inc1_p10            earnings
# mn_earn_wne_inc2_p10            earnings
# mn_earn_wne_inc3_p10            earnings
# mn_earn_wne_indep0_inc1_p10     earnings
# mn_earn_wne_indep0_p10          earnings
# mn_earn_wne_indep1_p10          earnings
# mn_earn_wne_male0_p10           earnings
# mn_earn_wne_male1_p10           earnings
# count_nwne_p6                   earnings
# count_wne_p6                    earnings
# mn_earn_wne_p6                  earnings
# md_earn_wne_p6                  earnings
# pct10_earn_wne_p6               earnings
# pct25_earn_wne_p6               earnings
# pct75_earn_wne_p6               earnings
# pct90_earn_wne_p6               earnings
# sd_earn_wne_p6                  earnings
# count_wne_inc1_p6               earnings
# count_wne_inc2_p6               earnings
# count_wne_inc3_p6               earnings
# count_wne_indep0_inc1_p6        earnings
# count_wne_indep0_p6             earnings
# count_wne_indep1_p6             earnings
# count_wne_male0_p6              earnings
# count_wne_male1_p6              earnings
# gt_25k_p6                       earnings
# mn_earn_wne_inc1_p6             earnings
# mn_earn_wne_inc2_p6             earnings
# mn_earn_wne_inc3_p6             earnings
# mn_earn_wne_indep0_inc1_p6      earnings
# mn_earn_wne_indep0_p6           earnings
# mn_earn_wne_indep1_p6           earnings
# mn_earn_wne_male0_p6            earnings
# mn_earn_wne_male1_p6            earnings
# count_nwne_p7                   earnings
# count_wne_p7                    earnings
# mn_earn_wne_p7                  earnings
# sd_earn_wne_p7                  earnings
# gt_25k_p7                       earnings
# count_nwne_p8                   earnings
# count_wne_p8                    earnings
# mn_earn_wne_p8                  earnings
# md_earn_wne_p8                  earnings
# pct10_earn_wne_p8               earnings
# pct25_earn_wne_p8               earnings
# pct75_earn_wne_p8               earnings
# pct90_earn_wne_p8               earnings
# sd_earn_wne_p8                  earnings
# gt_25k_p8                       earnings
# count_nwne_p9                   earnings
# count_wne_p9                    earnings
# mn_earn_wne_p9                  earnings
# sd_earn_wne_p9                  earnings
# gt_25k_p9                       earnings
#
#                                                                                developer-friendly name  \
# VARIABLE NAME
# count_ed                                                                                 student_count
# count_nwne_p10                                     10_yrs_after_entry.not_working_not_enrolled.overall
# count_wne_p10                                          10_yrs_after_entry.working_not_enrolled.overall
# mn_earn_wne_p10                                  10_yrs_after_entry.working_not_enrolled.mean_earnings
# md_earn_wne_p10                                                              10_yrs_after_entry.median
# pct10_earn_wne_p10                      10_yrs_after_entry.working_not_enrolled.earnings_percentile.10
# pct25_earn_wne_p10                      10_yrs_after_entry.working_not_enrolled.earnings_percentile.25
# pct75_earn_wne_p10                      10_yrs_after_entry.working_not_enrolled.earnings_percentile.75
# pct90_earn_wne_p10                      10_yrs_after_entry.working_not_enrolled.earnings_percentile.90
# sd_earn_wne_p10                                        10_yrs_after_entry.working_not_enrolled.std_dev
# count_wne_inc1_p10                       10_yrs_after_entry.working_not_enrolled.income.lowest_tercile
# count_wne_inc2_p10                       10_yrs_after_entry.working_not_enrolled.income.middle_tercile
# count_wne_inc3_p10                      10_yrs_after_entry.working_not_enrolled.income.highest_tercile
# count_wne_indep0_inc1_p10    10_yrs_after_entry.working_not_enrolled.dependent_students_lowest_tercile
# count_wne_indep0_p10                        10_yrs_after_entry.working_not_enrolled.dependent_students
# count_wne_indep1_p10                                           10_yrs_after_entry.independent_students
# count_wne_male0_p10                                                 10_yrs_after_entry.female_students
# count_wne_male1_p10                                                   10_yrs_after_entry.male_students
# gt_25k_p10                                               10_yrs_after_entry.percent_greater_than_25000
# mn_earn_wne_inc1_p10                                   10_yrs_after_entry.mean_earnings.lowest_tercile
# mn_earn_wne_inc2_p10                                   10_yrs_after_entry.mean_earnings.middle_tercile
# mn_earn_wne_inc3_p10                                  10_yrs_after_entry.mean_earnings.highest_tercile
# mn_earn_wne_indep0_inc1_p10         10_yrs_after_entry.mean_earnings.dependent_students_lowest_tercile
# mn_earn_wne_indep0_p10                             10_yrs_after_entry.mean_earnings.dependent_students
# mn_earn_wne_indep1_p10                           10_yrs_after_entry.mean_earnings.independent_students
# mn_earn_wne_male0_p10                                 10_yrs_after_entry.mean_earnings.female_students
# mn_earn_wne_male1_p10                                   10_yrs_after_entry.mean_earnings.male_students
# count_nwne_p6                                       6_yrs_after_entry.not_working_not_enrolled.overall
# count_wne_p6                                            6_yrs_after_entry.working_not_enrolled.overall
# mn_earn_wne_p6                                    6_yrs_after_entry.working_not_enrolled.mean_earnings
# md_earn_wne_p6                                                                6_yrs_after_entry.median
# pct10_earn_wne_p6                        6_yrs_after_entry.working_not_enrolled.earnings_percentile.10
# pct25_earn_wne_p6                        6_yrs_after_entry.working_not_enrolled.earnings_percentile.25
# pct75_earn_wne_p6                        6_yrs_after_entry.working_not_enrolled.earnings_percentile.75
# pct90_earn_wne_p6                        6_yrs_after_entry.working_not_enrolled.earnings_percentile.90
# sd_earn_wne_p6                                          6_yrs_after_entry.working_not_enrolled.std_dev
# count_wne_inc1_p6                         6_yrs_after_entry.working_not_enrolled.income.lowest_tercile
# count_wne_inc2_p6                         6_yrs_after_entry.working_not_enrolled.income.middle_tercile
# count_wne_inc3_p6                        6_yrs_after_entry.working_not_enrolled.income.highest_tercile
# count_wne_indep0_inc1_p6      6_yrs_after_entry.working_not_enrolled.dependent_students_lowest_tercile
# count_wne_indep0_p6                          6_yrs_after_entry.working_not_enrolled.dependent_students
# count_wne_indep1_p6                                             6_yrs_after_entry.independent_students
# count_wne_male0_p6                                                   6_yrs_after_entry.female_students
# count_wne_male1_p6                                                     6_yrs_after_entry.male_students
# gt_25k_p6                                                 6_yrs_after_entry.percent_greater_than_25000
# mn_earn_wne_inc1_p6                                     6_yrs_after_entry.mean_earnings.lowest_tercile
# mn_earn_wne_inc2_p6                                     6_yrs_after_entry.mean_earnings.middle_tercile
# mn_earn_wne_inc3_p6                                    6_yrs_after_entry.mean_earnings.highest_tercile
# mn_earn_wne_indep0_inc1_p6           6_yrs_after_entry.mean_earnings.dependent_students_lowest_tercile
# mn_earn_wne_indep0_p6                               6_yrs_after_entry.mean_earnings.dependent_students
# mn_earn_wne_indep1_p6                             6_yrs_after_entry.mean_earnings.independent_students
# mn_earn_wne_male0_p6                                   6_yrs_after_entry.mean_earnings.female_students
# mn_earn_wne_male1_p6                                     6_yrs_after_entry.mean_earnings.male_students
# count_nwne_p7                                               7_yrs_after_entry.not_working_not_enrolled
# count_wne_p7                                                    7_yrs_after_entry.working_not_enrolled
# mn_earn_wne_p7                                                         7_yrs_after_entry.mean_earnings
# sd_earn_wne_p7                                                               7_yrs_after_entry.std_dev
# gt_25k_p7                                                 7_yrs_after_entry.percent_greater_than_25000
# count_nwne_p8                                               8_yrs_after_entry.not_working_not_enrolled
# count_wne_p8                                                    8_yrs_after_entry.working_not_enrolled
# mn_earn_wne_p8                                                         8_yrs_after_entry.mean_earnings
# md_earn_wne_p8                                                       8_yrs_after_entry.median_earnings
# pct10_earn_wne_p8                                           8_yrs_after_entry.10th_percentile_earnings
# pct25_earn_wne_p8                                           8_yrs_after_entry.25th_percentile_earnings
# pct75_earn_wne_p8                                           8_yrs_after_entry.75th_percentile_earnings
# pct90_earn_wne_p8                                           8_yrs_after_entry.90th_percentile_earnings
# sd_earn_wne_p8                                                         8_yrs_after_entry.std_deviation
# gt_25k_p8                                                 8_yrs_after_entry.percent_greater_than_25000
# count_nwne_p9                                               9_yrs_after_entry.not_working_not_enrolled
# count_wne_p9                                                    9_yrs_after_entry.working_not_enrolled
# mn_earn_wne_p9                                                         9_yrs_after_entry.mean_earnings
# sd_earn_wne_p9                                                         9_yrs_after_entry.std_deviation
# gt_25k_p9                                                 9_yrs_after_entry.percent_greater_than_25000
#
#                             API data type VALUE LABEL    SOURCE NOTES
# VARIABLE NAME
# count_ed                          integer   NaN   NaN  Treasury   NaN
# count_nwne_p10                    integer   NaN   NaN  Treasury   NaN
# count_wne_p10                     integer   NaN   NaN  Treasury   NaN
# mn_earn_wne_p10                   integer   NaN   NaN  Treasury   NaN
# md_earn_wne_p10                   integer   NaN   NaN  Treasury   NaN
# pct10_earn_wne_p10                integer   NaN   NaN  Treasury   NaN
# pct25_earn_wne_p10                integer   NaN   NaN  Treasury   NaN
# pct75_earn_wne_p10                integer   NaN   NaN  Treasury   NaN
# pct90_earn_wne_p10                integer   NaN   NaN  Treasury   NaN
# sd_earn_wne_p10                   integer   NaN   NaN  Treasury   NaN
# count_wne_inc1_p10                integer   NaN   NaN  Treasury   NaN
# count_wne_inc2_p10                integer   NaN   NaN  Treasury   NaN
# count_wne_inc3_p10                integer   NaN   NaN  Treasury   NaN
# count_wne_indep0_inc1_p10         integer   NaN   NaN  Treasury   NaN
# count_wne_indep0_p10              integer   NaN   NaN  Treasury   NaN
# count_wne_indep1_p10              integer   NaN   NaN  Treasury   NaN
# count_wne_male0_p10               integer   NaN   NaN  Treasury   NaN
# count_wne_male1_p10               integer   NaN   NaN  Treasury   NaN
# gt_25k_p10                          float   NaN   NaN  Treasury   NaN
# mn_earn_wne_inc1_p10              integer   NaN   NaN  Treasury   NaN
# mn_earn_wne_inc2_p10              integer   NaN   NaN  Treasury   NaN
# mn_earn_wne_inc3_p10              integer   NaN   NaN  Treasury   NaN
# mn_earn_wne_indep0_inc1_p10       integer   NaN   NaN  Treasury   NaN
# mn_earn_wne_indep0_p10            integer   NaN   NaN  Treasury   NaN
# mn_earn_wne_indep1_p10            integer   NaN   NaN  Treasury   NaN
# mn_earn_wne_male0_p10             integer   NaN   NaN  Treasury   NaN
# mn_earn_wne_male1_p10             integer   NaN   NaN  Treasury   NaN
# count_nwne_p6                     integer   NaN   NaN  Treasury   NaN
# count_wne_p6                      integer   NaN   NaN  Treasury   NaN
# mn_earn_wne_p6                    integer   NaN   NaN  Treasury   NaN
# md_earn_wne_p6                    integer   NaN   NaN  Treasury   NaN
# pct10_earn_wne_p6                 integer   NaN   NaN  Treasury   NaN
# pct25_earn_wne_p6                 integer   NaN   NaN  Treasury   NaN
# pct75_earn_wne_p6                 integer   NaN   NaN  Treasury   NaN
# pct90_earn_wne_p6                 integer   NaN   NaN  Treasury   NaN
# sd_earn_wne_p6                    integer   NaN   NaN  Treasury   NaN
# count_wne_inc1_p6                 integer   NaN   NaN  Treasury   NaN
# count_wne_inc2_p6                 integer   NaN   NaN  Treasury   NaN
# count_wne_inc3_p6                 integer   NaN   NaN  Treasury   NaN
# count_wne_indep0_inc1_p6          integer   NaN   NaN  Treasury   NaN
# count_wne_indep0_p6               integer   NaN   NaN  Treasury   NaN
# count_wne_indep1_p6               integer   NaN   NaN  Treasury   NaN
# count_wne_male0_p6                integer   NaN   NaN  Treasury   NaN
# count_wne_male1_p6                integer   NaN   NaN  Treasury   NaN
# gt_25k_p6                           float   NaN   NaN  Treasury   NaN
# mn_earn_wne_inc1_p6                 float   NaN   NaN  Treasury   NaN
# mn_earn_wne_inc2_p6                 float   NaN   NaN  Treasury   NaN
# mn_earn_wne_inc3_p6                 float   NaN   NaN  Treasury   NaN
# mn_earn_wne_indep0_inc1_p6          float   NaN   NaN  Treasury   NaN
# mn_earn_wne_indep0_p6               float   NaN   NaN  Treasury   NaN
# mn_earn_wne_indep1_p6               float   NaN   NaN  Treasury   NaN
# mn_earn_wne_male0_p6                float   NaN   NaN  Treasury   NaN
# mn_earn_wne_male1_p6                float   NaN   NaN  Treasury   NaN
# count_nwne_p7                       float   NaN   NaN  Treasury   NaN
# count_wne_p7                      integer   NaN   NaN  Treasury   NaN
# mn_earn_wne_p7                      float   NaN   NaN  Treasury   NaN
# sd_earn_wne_p7                      float   NaN   NaN  Treasury   NaN
# gt_25k_p7                           float   NaN   NaN  Treasury   NaN
# count_nwne_p8                     integer   NaN   NaN  Treasury   NaN
# count_wne_p8                      integer   NaN   NaN  Treasury   NaN
# mn_earn_wne_p8                      float   NaN   NaN  Treasury   NaN
# md_earn_wne_p8                      float   NaN   NaN  Treasury   NaN
# pct10_earn_wne_p8                 integer   NaN   NaN  Treasury   NaN
# pct25_earn_wne_p8                 integer   NaN   NaN  Treasury   NaN
# pct75_earn_wne_p8                 integer   NaN   NaN  Treasury   NaN
# pct90_earn_wne_p8                 integer   NaN   NaN  Treasury   NaN
# sd_earn_wne_p8                      float   NaN   NaN  Treasury   NaN
# gt_25k_p8                           float   NaN   NaN  Treasury   NaN
# count_nwne_p9                     integer   NaN   NaN  Treasury   NaN
# count_wne_p9                      integer   NaN   NaN  Treasury   NaN
# mn_earn_wne_p9                      float   NaN   NaN  Treasury   NaN
# sd_earn_wne_p9                      float   NaN   NaN  Treasury   NaN
# gt_25k_p9                           float   NaN   NaN  Treasury   NaN

# %%
student
# Out:
#                                                                                                   NAME OF DATA ELEMENT  \
# VARIABLE NAME
# UGDS                                                               Enrollment of undergraduate degree-seeking students
# UG                                                                            Enrollment of all undergraduate students
# UGDS_WHITE                            Total share of enrollment of undergraduate degree-seeking students who are white
# UGDS_BLACK                            Total share of enrollment of undergraduate degree-seeking students who are black
# UGDS_HISP                          Total share of enrollment of undergraduate degree-seeking students who are Hispanic
# UGDS_ASIAN                            Total share of enrollment of undergraduate degree-seeking students who are Asian
# UGDS_AIAN          Total share of enrollment of undergraduate degree-seeking students who are American Indian/Alask...
# UGDS_NHPI          Total share of enrollment of undergraduate degree-seeking students who are Native Hawaiian/Pacif...
# UGDS_2MOR                 Total share of enrollment of undergraduate degree-seeking students who are two or more races
# UGDS_NRA                Total share of enrollment of undergraduate degree-seeking students who are non-resident aliens
# UGDS_UNKN                     Total share of enrollment of undergraduate degree-seeking students whose race is unknown
# UGDS_WHITENH             Total share of enrollment of undergraduate degree-seeking students who are white non-Hispanic
# UGDS_BLACKNH             Total share of enrollment of undergraduate degree-seeking students who are black non-Hispanic
# UGDS_API             Total share of enrollment of undergraduate degree-seeking students who are Asian/Pacific Islander
# UGDS_AIANOld       Total share of enrollment of undergraduate degree-seeking students who are American Indian/Alask...
# UGDS_HISPOld                       Total share of enrollment of undergraduate degree-seeking students who are Hispanic
# UG_NRA                                 Total share of enrollment of undergraduate students who are non-resident aliens
# UG_UNKN                                      Total share of enrollment of undergraduate students whose race is unknown
# UG_WHITENH                              Total share of enrollment of undergraduate students who are white non-Hispanic
# UG_BLACKNH                              Total share of enrollment of undergraduate students who are black non-Hispanic
# UG_API                              Total share of enrollment of undergraduate students who are Asian/Pacific Islander
# UG_AIANOld                   Total share of enrollment of undergraduate students who are American Indian/Alaska Native
# UG_HISPOld                                        Total share of enrollment of undergraduate students who are Hispanic
# PPTUG_EF                                Share of undergraduate, degree-/certificate-seeking students who are part-time
# PPTUG_EF2                               Share of undergraduate, degree-/certificate-seeking students who are part-time
# PFTFTUG1_EF        Share of undergraduate students who are first-time, full-time degree-/certificate-seeking underg...
# RET_FT4                                         First-time, full-time student retention rate at four-year institutions
# RET_FTL4                              First-time, full-time student retention rate at less-than-four-year institutions
# RET_PT4                                         First-time, part-time student retention rate at four-year institutions
# RET_PTL4                              First-time, part-time student retention rate at less-than-four-year institutions
# UG25abv                                                                 Percentage of undergraduates aged 25 and above
# INC_PCT_LO                                      Percentage of aided students whose family income is between $0-$30,000
# DEP_STAT_PCT_IND                                                Percentage of students who are financially independent
# DEP_INC_PCT_LO        Percentage of students who are financially independent and have family incomes between $0-30,000
# IND_INC_PCT_LO          Percentage of students who are financially dependent and have family incomes between $0-30,000
# PAR_ED_PCT_1STGEN                                                                 Percentage first-generation students
# INC_PCT_M1                               Aided students with family incomes between $30,001-$48,000 in nominal dollars
# INC_PCT_M2                               Aided students with family incomes between $48,001-$75,000 in nominal dollars
# INC_PCT_H1                              Aided students with family incomes between $75,001-$110,000 in nominal dollars
# INC_PCT_H2                                     Aided students with family incomes between $110,001+ in nominal dollars
# DEP_INC_PCT_M1                       Dependent students with family incomes between $30,001-$48,000 in nominal dollars
# DEP_INC_PCT_M2                       Dependent students with family incomes between $48,001-$75,000 in nominal dollars
# DEP_INC_PCT_H1                      Dependent students with family incomes between $75,001-$110,000 in nominal dollars
# DEP_INC_PCT_H2                             Dependent students with family incomes between $110,001+ in nominal dollars
# IND_INC_PCT_M1                     Independent students with family incomes between $30,001-$48,000 in nominal dollars
# IND_INC_PCT_M2                     Independent students with family incomes between $48,001-$75,000 in nominal dollars
# IND_INC_PCT_H1                    Independent students with family incomes between $75,001-$110,000 in nominal dollars
# IND_INC_PCT_H2                           Independent students with family incomes between $110,001+ in nominal dollars
# PAR_ED_PCT_MS                            Percent of students whose parents' highest educational level is middle school
# PAR_ED_PCT_HS                              Percent of students whose parents' highest educational level is high school
# PAR_ED_PCT_PS      Percent of students whose parents' highest educational level was is some form of postsecondary e...
# APPL_SCH_PCT_GE2                                                  Number of applications is greater than or equal to 2
# APPL_SCH_PCT_GE3                                                  Number of applications is greater than or equal to 3
# APPL_SCH_PCT_GE4                                                  Number of applications is greater than or equal to 4
# APPL_SCH_PCT_GE5                                                  Number of applications is greater than or equal to 5
# DEP_INC_AVG                                          Average family income of dependent students in real 2014 dollars.
# IND_INC_AVG                                       Average family income of independent students in real 2014 dollars.
# INC_N                                                                   Number of students in the family income cohort
# DEP_INC_N                                            Number of students in the family income dependent students cohort
# IND_INC_N                                          Number of students in the family income independent students cohort
# DEP_STAT_N                                       Number of students in the disaggregation with valid dependency status
# PAR_ED_N                                                     Number of students in the parents' education level cohort
# APPL_SCH_N                                                         Number of students in the FAFSA applications cohort
# pell_ever                                                  Share of students who received a Pell Grant while in school
# age_entry                                                                           Average age of entry, via SSA data
# age_entry_sq                                                                       Average of the age of entry squared
# agege24                                                                           Percent of students over 23 at entry
# female                                                                          Share of female students, via SSA data
# married                                                                                      Share of married students
# dependent                                                                                  Share of dependent students
# veteran                                                                                      Share of veteran students
# first_gen                                                                           Share of first-generation students
# faminc                                                                                           Average family income
# md_faminc                                                                                         Median family income
# faminc_ind                                                              Average family income for independent students
# lnfaminc                                                                           Average of the log of family income
# lnfaminc_ind                                              Average of the log of family income for independent students
# pct_white                            Percent of the population from students' zip codes that is White, via Census data
# pct_black                            Percent of the population from students' zip codes that is Black, via Census data
# pct_asian                            Percent of the population from students' zip codes that is Asian, via Census data
# pct_hispanic                      Percent of the population from students' zip codes that is Hispanic, via Census data
# pct_ba             Percent of the population from students' zip codes with a bachelor's degree over the age 25, via...
# pct_grad_prof      Percent of the population from students' zip codes over 25 with a professional degree, via Censu...
# pct_born_us                Percent of the population from students' zip codes that was born in the US, via Census data
# median_hh_inc                                                                                  Median household income
# poverty_rate                                                                             Poverty rate, via Census data
# unemp_rate                                                                          Unemployment rate, via Census data
# ln_median_hh_inc                                                                    Log of the median household income
# fsend_count                                    Number of students who sent their FAFSA reports to at least one college
# fsend_1                                                     Share of students who submitted FAFSAs to only one college
# fsend_2                                                         Share of students who submitted FAFSAs to two colleges
# fsend_3                                                       Share of students who submitted FAFSAs to three colleges
# fsend_4                                                        Share of students who submitted FAFSAs to four colleges
# fsend_5                                               Share of students who submitted FAFSAs to at least five colleges
#
#                   dev-category  \
# VARIABLE NAME
# UGDS                   student
# UG                     student
# UGDS_WHITE             student
# UGDS_BLACK             student
# UGDS_HISP              student
# UGDS_ASIAN             student
# UGDS_AIAN              student
# UGDS_NHPI              student
# UGDS_2MOR              student
# UGDS_NRA               student
# UGDS_UNKN              student
# UGDS_WHITENH           student
# UGDS_BLACKNH           student
# UGDS_API               student
# UGDS_AIANOld           student
# UGDS_HISPOld           student
# UG_NRA                 student
# UG_UNKN                student
# UG_WHITENH             student
# UG_BLACKNH             student
# UG_API                 student
# UG_AIANOld             student
# UG_HISPOld             student
# PPTUG_EF               student
# PPTUG_EF2              student
# PFTFTUG1_EF            student
# RET_FT4                student
# RET_FTL4               student
# RET_PT4                student
# RET_PTL4               student
# UG25abv                student
# INC_PCT_LO             student
# DEP_STAT_PCT_IND       student
# DEP_INC_PCT_LO         student
# IND_INC_PCT_LO         student
# PAR_ED_PCT_1STGEN      student
# INC_PCT_M1             student
# INC_PCT_M2             student
# INC_PCT_H1             student
# INC_PCT_H2             student
# DEP_INC_PCT_M1         student
# DEP_INC_PCT_M2         student
# DEP_INC_PCT_H1         student
# DEP_INC_PCT_H2         student
# IND_INC_PCT_M1         student
# IND_INC_PCT_M2         student
# IND_INC_PCT_H1         student
# IND_INC_PCT_H2         student
# PAR_ED_PCT_MS          student
# PAR_ED_PCT_HS          student
# PAR_ED_PCT_PS          student
# APPL_SCH_PCT_GE2       student
# APPL_SCH_PCT_GE3       student
# APPL_SCH_PCT_GE4       student
# APPL_SCH_PCT_GE5       student
# DEP_INC_AVG            student
# IND_INC_AVG            student
# INC_N                  student
# DEP_INC_N              student
# IND_INC_N              student
# DEP_STAT_N             student
# PAR_ED_N               student
# APPL_SCH_N             student
# pell_ever              student
# age_entry              student
# age_entry_sq           student
# agege24                student
# female                 student
# married                student
# dependent              student
# veteran                student
# first_gen              student
# faminc                 student
# md_faminc              student
# faminc_ind             student
# lnfaminc               student
# lnfaminc_ind           student
# pct_white              student
# pct_black              student
# pct_asian              student
# pct_hispanic           student
# pct_ba                 student
# pct_grad_prof          student
# pct_born_us            student
# median_hh_inc          student
# poverty_rate           student
# unemp_rate             student
# ln_median_hh_inc       student
# fsend_count            student
# fsend_1                student
# fsend_2                student
# fsend_3                student
# fsend_4                student
# fsend_5                student
#
#                                                  developer-friendly name  \
# VARIABLE NAME
# UGDS                                                                size
# UG                                                        enrollment.all
# UGDS_WHITE                             demographics.race_ethnicity.white
# UGDS_BLACK                             demographics.race_ethnicity.black
# UGDS_HISP                           demographics.race_ethnicity.hispanic
# UGDS_ASIAN                             demographics.race_ethnicity.asian
# UGDS_AIAN                               demographics.race_ethnicity.aian
# UGDS_NHPI                               demographics.race_ethnicity.nhpi
# UGDS_2MOR                        demographics.race_ethnicity.two_or_more
# UGDS_NRA                  demographics.race_ethnicity.non_resident_alien
# UGDS_UNKN                            demographics.race_ethnicity.unknown
# UGDS_WHITENH              demographics.race_ethnicity.white_non_hispanic
# UGDS_BLACKNH              demographics.race_ethnicity.black_non_hispanic
# UGDS_API              demographics.race_ethnicity.asian_pacific_islander
# UGDS_AIANOld                 demographics.race_ethnicity.aian_prior_2009
# UGDS_HISPOld             demographics.race_ethnicity.hispanic_prior_2009
# UG_NRA                             demographics.non_resident_aliens_2000
# UG_UNKN                         demographics.race_ethnicity.unknown_2000
# UG_WHITENH                        demographics.race_ethnicity.white_2000
# UG_BLACKNH                        demographics.race_ethnicity.black_2000
# UG_API                              demographics.race_ethnicity.api_2000
# UG_AIANOld                         demographics.race_ethnicity.aian_2000
# UG_HISPOld                     demographics.race_ethnicity.hispanic_2000
# PPTUG_EF                                                 part_time_share
# PPTUG_EF2                                                part_time_share
# PFTFTUG1_EF                                   share_first.time_full.time
# RET_FT4                               retention_rate.four_year.full_time
# RET_FTL4                           retention_rate.lt_four_year.full_time
# RET_PT4                               retention_rate.four_year.part_time
# RET_PTL4                           retention_rate.lt_four_year.part_time
# UG25abv                                                   share_25_older
# INC_PCT_LO                                       share_lowincome.0_30000
# DEP_STAT_PCT_IND                              share_independent_students
# DEP_INC_PCT_LO                       share_independent_lowincome.0_30000
# IND_INC_PCT_LO                        share_dependent_lowincome.0_300000
# PAR_ED_PCT_1STGEN                                  share_firstgeneration
# INC_PCT_M1                                share_middleincome.30001_48000
# INC_PCT_M2                                share_middleincome.30001_48000
# INC_PCT_H1                                 share_highincome.75001_110000
# INC_PCT_H2                                   share_highincome.110001plus
# DEP_INC_PCT_M1                 share_dependent_middleincome.300001_48000
# DEP_INC_PCT_M2                  share_dependent_middleincome.48001_75000
# DEP_INC_PCT_H1                   share_dependent_highincome.75001_110000
# DEP_INC_PCT_H2                     share_dependent_highincome.110001plus
# IND_INC_PCT_M1                share_independent_middleincome.30001_48000
# IND_INC_PCT_M2                share_independent_middleincome.48001_75000
# IND_INC_PCT_H1                 share_independent_highincome.75001_110000
# IND_INC_PCT_H2                   share_independent_highincome.110001plus
# PAR_ED_PCT_MS                 share_firstgeneration_parents.middleschool
# PAR_ED_PCT_HS                   share_firstgeneration_parents.highschool
# PAR_ED_PCT_PS                  share_firstgeneration_parents.somecollege
# APPL_SCH_PCT_GE2                             fafsa_sent.2_college_allyrs
# APPL_SCH_PCT_GE3                             fafsa_sent.3_college_allyrs
# APPL_SCH_PCT_GE4                             fafsa_sent.4_college_allyrs
# APPL_SCH_PCT_GE5                         fafsa_sent.5plus_college_allyrs
# DEP_INC_AVG                             avg_dependent_income.2014dollars
# IND_INC_AVG                           avg_independent_income.2014dollars
# INC_N                                              family_income.overall
# DEP_INC_N                               family_income.dependent_students
# IND_INC_N                             family_income.independent_students
# DEP_STAT_N                                       valid_dependency_status
# PAR_ED_N                                         parents_education_level
# APPL_SCH_N                                            FAFSA_applications
# pell_ever                                       students_with_pell_grant
# age_entry                                         demographics.age_entry
# age_entry_sq                              demographics.age_entry_squared
# agege24                                    demographics.over_23_at_entry
# female                                         demographics.female_share
# married                                             demographics.married
# dependent                                         demographics.dependent
# veteran                                             demographics.veteran
# first_gen                                  demographics.first_generation
# faminc                                    demographics.avg_family_income
# md_faminc                              demographics.median_family_income
# faminc_ind                   demographics.avg_family_income_independents
# lnfaminc                              demographics.avg_family_income_log
# lnfaminc_ind             demographics.avg_family_income_independents_log
# pct_white                              demographics.share_white.home_ZIP
# pct_black                              demographics.share_black.home_ZIP
# pct_asian                              demographics.share_asian.home_ZIP
# pct_hispanic                        demographics.share_hispanic.home_ZIP
# pct_ba                demographics.share_bachelors_degree_age25.home_ZIP
# pct_grad_prof      demographics.share_professional_degree_age25.home_ZIP
# pct_born_us                          demographics.share_born_US.home_ZIP
# median_hh_inc                              demographics.median_hh_income
# poverty_rate                                   demographics.poverty_rate
# unemp_rate                                     demographics.unemployment
# ln_median_hh_inc                       demographics.median_hh_income_log
# fsend_count                                           fafsa_sent.overall
# fsend_1                                             fafsa_sent.1_college
# fsend_2                                            fafsa_sent.2_colleges
# fsend_3                                             fafsa_sent.3_college
# fsend_4                                            fafsa_sent.4_colleges
# fsend_5                                    fafsa_sent.5_or_more_colleges
#
#                   API data type VALUE LABEL    SOURCE  \
# VARIABLE NAME
# UGDS                    integer         NaN     IPEDS
# UG                      integer   NaN   NaN     IPEDS
# UGDS_WHITE                float   NaN   NaN     IPEDS
# UGDS_BLACK                float   NaN   NaN     IPEDS
# UGDS_HISP                 float   NaN   NaN     IPEDS
# UGDS_ASIAN                float   NaN   NaN     IPEDS
# UGDS_AIAN                 float   NaN   NaN     IPEDS
# UGDS_NHPI                 float   NaN   NaN     IPEDS
# UGDS_2MOR                 float   NaN   NaN     IPEDS
# UGDS_NRA                  float   NaN   NaN     IPEDS
# UGDS_UNKN                 float   NaN   NaN     IPEDS
# UGDS_WHITENH              float   NaN   NaN     IPEDS
# UGDS_BLACKNH              float   NaN   NaN     IPEDS
# UGDS_API                  float   NaN   NaN     IPEDS
# UGDS_AIANOld              float   NaN   NaN     IPEDS
# UGDS_HISPOld              float   NaN   NaN     IPEDS
# UG_NRA                    float   NaN   NaN     IPEDS
# UG_UNKN                   float   NaN   NaN     IPEDS
# UG_WHITENH                float   NaN   NaN     IPEDS
# UG_BLACKNH                float   NaN   NaN     IPEDS
# UG_API                    float   NaN   NaN     IPEDS
# UG_AIANOld                float   NaN   NaN     IPEDS
# UG_HISPOld                float   NaN   NaN     IPEDS
# PPTUG_EF                  float         NaN     IPEDS
# PPTUG_EF2                 float   NaN   NaN     IPEDS
# PFTFTUG1_EF               float         NaN     IPEDS
# RET_FT4                   float   NaN   NaN     IPEDS
# RET_FTL4                  float   NaN   NaN     IPEDS
# RET_PT4                   float   NaN   NaN     IPEDS
# RET_PTL4                  float   NaN   NaN     IPEDS
# UG25abv                   float         NaN     IPEDS
# INC_PCT_LO                float   NaN   NaN     NSLDS
# DEP_STAT_PCT_IND          float   NaN   NaN     NSLDS
# DEP_INC_PCT_LO            float   NaN   NaN     NSLDS
# IND_INC_PCT_LO            float   NaN   NaN     NSLDS
# PAR_ED_PCT_1STGEN         float   NaN   NaN     NSLDS
# INC_PCT_M1                float   NaN   NaN     NSLDS
# INC_PCT_M2                float   NaN   NaN     NSLDS
# INC_PCT_H1                float   NaN   NaN     NSLDS
# INC_PCT_H2                float   NaN   NaN     NSLDS
# DEP_INC_PCT_M1            float   NaN   NaN     NSLDS
# DEP_INC_PCT_M2            float   NaN   NaN     NSLDS
# DEP_INC_PCT_H1            float   NaN   NaN     NSLDS
# DEP_INC_PCT_H2            float   NaN   NaN     NSLDS
# IND_INC_PCT_M1            float   NaN   NaN     NSLDS
# IND_INC_PCT_M2            float   NaN   NaN     NSLDS
# IND_INC_PCT_H1            float   NaN   NaN     NSLDS
# IND_INC_PCT_H2            float   NaN   NaN     NSLDS
# PAR_ED_PCT_MS             float         NaN     NSLDS
# PAR_ED_PCT_HS             float         NaN     NSLDS
# PAR_ED_PCT_PS             float         NaN     NSLDS
# APPL_SCH_PCT_GE2          float   NaN   NaN     NSLDS
# APPL_SCH_PCT_GE3          float   NaN   NaN     NSLDS
# APPL_SCH_PCT_GE4          float   NaN   NaN     NSLDS
# APPL_SCH_PCT_GE5          float   NaN   NaN     NSLDS
# DEP_INC_AVG             integer   NaN   NaN     NSLDS
# IND_INC_AVG             integer   NaN   NaN     NSLDS
# INC_N                   integer   NaN   NaN     NSLDS
# DEP_INC_N               integer   NaN   NaN     NSLDS
# IND_INC_N               integer   NaN   NaN     NSLDS
# DEP_STAT_N              integer   NaN   NaN     NSLDS
# PAR_ED_N                integer   NaN   NaN     NSLDS
# APPL_SCH_N              integer   NaN   NaN     NSLDS
# pell_ever                 float   NaN   NaN  Treasury
# age_entry               integer   NaN   NaN  Treasury
# age_entry_sq            integer   NaN   NaN  Treasury
# agege24                   float   NaN   NaN  Treasury
# female                    float   NaN   NaN  Treasury
# married                   float   NaN   NaN  Treasury
# dependent                 float   NaN   NaN  Treasury
# veteran                   float   NaN   NaN  Treasury
# first_gen                 float   NaN   NaN  Treasury
# faminc                  integer   NaN   NaN  Treasury
# md_faminc               integer   NaN   NaN  Treasury
# faminc_ind              integer   NaN   NaN  Treasury
# lnfaminc                integer   NaN   NaN  Treasury
# lnfaminc_ind            integer   NaN   NaN  Treasury
# pct_white                 float   NaN   NaN  Treasury
# pct_black                 float   NaN   NaN  Treasury
# pct_asian                 float   NaN   NaN  Treasury
# pct_hispanic              float   NaN   NaN  Treasury
# pct_ba                    float   NaN   NaN  Treasury
# pct_grad_prof             float   NaN   NaN  Treasury
# pct_born_us               float   NaN   NaN  Treasury
# median_hh_inc           integer   NaN   NaN  Treasury
# poverty_rate              float   NaN   NaN  Treasury
# unemp_rate                float   NaN   NaN  Treasury
# ln_median_hh_inc        integer   NaN   NaN  Treasury
# fsend_count             integer   NaN   NaN  Treasury
# fsend_1                   float   NaN   NaN  Treasury
# fsend_2                   float   NaN   NaN  Treasury
# fsend_3                   float   NaN   NaN  Treasury
# fsend_4                   float   NaN   NaN  Treasury
# fsend_5                   float   NaN   NaN  Treasury
#
#                                                                                                                  NOTES
# VARIABLE NAME
# UGDS                                         To be bucketed into size categories (College Navigator: <2k, 2-15k, >15k)
# UG                                                                                                                 NaN
# UGDS_WHITE                                                                                             Not before 2009
# UGDS_BLACK                                                                                               Pre2009_IPEDS
# UGDS_HISP                                                                                                          NaN
# UGDS_ASIAN                                                                                                         NaN
# UGDS_AIAN                                                                                                          NaN
# UGDS_NHPI                                                                                                          NaN
# UGDS_2MOR                                                                                                          NaN
# UGDS_NRA                                                                                                           NaN
# UGDS_UNKN                                                                                                          NaN
# UGDS_WHITENH                                                                     Not after 2009 (2009 transition year)
# UGDS_BLACKNH                                                                                                       NaN
# UGDS_API                                                                                                           NaN
# UGDS_AIANOld                                                                                                       NaN
# UGDS_HISPOld                                                                                                       NaN
# UG_NRA                                                                                                  Not after 2000
# UG_UNKN                                                                                                            NaN
# UG_WHITENH                                                                                                         NaN
# UG_BLACKNH                                                                                                         NaN
# UG_API                                                                                                             NaN
# UG_AIANOld                                                                                                         NaN
# UG_HISPOld                                                                                                         NaN
# PPTUG_EF           The proportion of degree/certificate-seeking undergraduates enrolled part time in the fall term,...
# PPTUG_EF2                                                                                               Not after 2000
# PFTFTUG1_EF                                                        May be published alongside C150_ to provide context
# RET_FT4            The proportion of full-time, first-time, degree/certificate-seeking undergraduates who were enro...
# RET_FTL4                                                                                                           NaN
# RET_PT4            The proportion of part-time, first-time, degree/certificate-seeking undergraduates who were enro...
# RET_PTL4                                                                                                           NaN
# UG25abv                                                      The proportion of undergraduates who are aged 25 or older
# INC_PCT_LO                                                                                                         NaN
# DEP_STAT_PCT_IND                                                                                                   NaN
# DEP_INC_PCT_LO                                                                                                     NaN
# IND_INC_PCT_LO                                                                                                     NaN
# PAR_ED_PCT_1STGEN                                                                                                  NaN
# INC_PCT_M1                                                                                                         NaN
# INC_PCT_M2                                                                                                         NaN
# INC_PCT_H1                                                                                                         NaN
# INC_PCT_H2                                                                                                         NaN
# DEP_INC_PCT_M1                                                                                                     NaN
# DEP_INC_PCT_M2                                                                                                     NaN
# DEP_INC_PCT_H1                                                                                                     NaN
# DEP_INC_PCT_H2                                                                                                     NaN
# IND_INC_PCT_M1                                                                                                     NaN
# IND_INC_PCT_M2                                                                                                     NaN
# IND_INC_PCT_H1                                                                                                     NaN
# IND_INC_PCT_H2                                                                                                     NaN
# PAR_ED_PCT_MS                                                                                                      NaN
# PAR_ED_PCT_HS                                                                                                      NaN
# PAR_ED_PCT_PS                                                                                                      NaN
# APPL_SCH_PCT_GE2                                                                                                   NaN
# APPL_SCH_PCT_GE3                                                                                                   NaN
# APPL_SCH_PCT_GE4                                                                                                   NaN
# APPL_SCH_PCT_GE5                                                                                                   NaN
# DEP_INC_AVG                                                                                                        NaN
# IND_INC_AVG                                                                                                        NaN
# INC_N                                                                                                              NaN
# DEP_INC_N                                                                                                          NaN
# IND_INC_N                                                                                                          NaN
# DEP_STAT_N                                                                                                         NaN
# PAR_ED_N                                                                                                           NaN
# APPL_SCH_N                                                                                                         NaN
# pell_ever                                                                                                          NaN
# age_entry                                                                                                          NaN
# age_entry_sq                                                                                                       NaN
# agege24                                                                                                            NaN
# female                                                                                                             NaN
# married                                                                                                            NaN
# dependent                                                                                                          NaN
# veteran                                                                                                            NaN
# first_gen                                                                                                          NaN
# faminc                                                                                                             NaN
# md_faminc                                                                                                          NaN
# faminc_ind                                                                                                         NaN
# lnfaminc                                                                                                           NaN
# lnfaminc_ind                                                                                                       NaN
# pct_white                                                                                                          NaN
# pct_black                                                                                                          NaN
# pct_asian                                                                                                          NaN
# pct_hispanic                                                                                                       NaN
# pct_ba                                                                                                             NaN
# pct_grad_prof                                                                                                      NaN
# pct_born_us                                                                                                        NaN
# median_hh_inc                                                                                                      NaN
# poverty_rate                                                                                                       NaN
# unemp_rate                                                                                                         NaN
# ln_median_hh_inc                                                                                                   NaN
# fsend_count                                                                                                        NaN
# fsend_1                                                                                                            NaN
# fsend_2                                                                                                            NaN
# fsend_3                                                                                                            NaN
# fsend_4                                                                                                            NaN
# fsend_5                                                                                                            NaN
